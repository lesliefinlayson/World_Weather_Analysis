# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# taolanaro mg
# comodoro rivadavia ar
# chokurdakh ru
# mar del plata ar
# arraial do cabo br
# busselton au
# cape town za
# broome au
# provideniya ru
# hasaki jp
# rikitea pf
# marquette us
# samalaeulu ws
# torbay ca
# saint-philippe re
# tasiilaq gl
# krasnyy yar ru
# illoqqortoormiut gl
# waingapu id
# saint-philippe re
# saskylakh ru
# hithadhoo mv
# charters towers au
# belushya guba ru
# jamestown sh
# maumere id
# taolanaro mg
# punta arenas cl
# vuktyl ru
# ahipara nz
# hilo us
# bredasdorp za
# jamestown sh
# abeche td
# bengkulu id
# nikolskoye ru
# lagoa pt
# rikitea pf
# ushuaia ar
# saint-joseph re
# bluff nz
# albany au
# port alfred za
# lompoc us
# coquimbo cl
# new norfolk au
# puerto ayora ec
# kruisfontein za
# hermanus za
# coquimbo cl
# rosarito mx
# kolosovka ru
# carnarvon au
# korla cn
# albany au
# lorengau pg
# cidreira br
# karaton kz
# barentsburg sj
# bredasdorp za
# arraial do cabo br
# hermanus za
# ushuaia ar
# fernley us
# sembabule ug
# qaqortoq gl
# barrow us
# ushuaia ar
# cherskiy ru
# hasaki jp
# porto santo pt
# ihtiman bg
# ushuaia ar
# jamestown sh
# albany au
# illoqqortoormiut gl
# zhigansk ru
# labuhan id
# saint george bm
# lebu cl
# saldanha za
# ekibastuz kz
# hithadhoo mv
# san cristobal ec
# kodiak us
# ostrovnoy ru
# tuktoyaktuk ca
# hilo us
# hermanus za
# rikitea pf
# saldanha za
# qaanaaq gl
# yellowknife ca
# butaritari ki
# stepnyak kz
# pevek ru
# jamestown sh
# whitecourt ca
# bandarbeyla so
# castro cl
# qui nhon vn
# kaitangata nz
# provideniya ru
# fairbanks us
# goderich sl
# punta arenas cl
# busselton au
# yellowknife ca
# sao pedro br
# tabou ci
# bubaque gw
# barentsburg sj
# albany au
# bathsheba bb
# albany au
# port hedland au
# castro cl
# atuona pf
# hermanus za
# carnarvon au
# bethel us
# saskylakh ru
# kahramanmaras tr
# sitka us
# butaritari ki
# zeya ru
# port alfred za
# arlit ne
# batagay ru
# atuona pf
# butaritari ki
# jamestown sh
# puerto ayora ec
# qaanaaq gl
# klaksvik fo
# bluff nz
# pittsburg us
# takoradi gh
# lakes entrance au
# bluff nz
# jamestown sh
# hilo us
# puruliya in
# khatanga ru
# carnarvon au
# saskylakh ru
# hilo us
# nacozari mx
# cockburn town tc
# guilin cn
# albany au
# albany au
# mataura pf
# katsuura jp
# punta arenas cl
# sentyabrskiy ru
# bethel us
# punta arenas cl
# hermanus za
# barrow us
# tubuala pa
# itarema br
# taolanaro mg
# mataura pf
# hovd mn
# ushuaia ar
# whitianga nz
# taolanaro mg
# busselton au
# lebu cl
# abu kamal sy
# punta arenas cl
# mahebourg mu
# ksenyevka ru
# belushya guba ru
# codrington ag
# chuy uy
# tawnat ma
# cap malheureux mu
# taolanaro mg
# arraial do cabo br
# saint-philippe re
# mazamari pe
# rikitea pf
# hobart au
# boali cf
# port pirie au
# avarua ck
# busselton au
# avarua ck
# vaini to
# ushuaia ar
# busselton au
# ushuaia ar
# katsuura jp
# busselton au
# muyezerskiy ru
# rikitea pf
# mataura pf
# kavieng pg
# mugur-aksy ru
# torbay ca
# bandarbeyla so
# jamestown sh
# port alfred za
# kapoeta sd
# lompoc us
# bredasdorp za
# new norfolk au
# hobart au
# east london za
# taolanaro mg
# hermanus za
# baruun-urt mn
# albany au
# chuy uy
# illoqqortoormiut gl
# chernyshevskiy ru
# yellowknife ca
# punta arenas cl
# khatanga ru
# hermanus za
# belushya guba ru
# mafinga tz
# saint-philippe re
# mataura pf
# bluff nz
# hermanus za
# hilo us
# svetlogorsk ru
# kloulklubed pw
# tezu in
# attawapiskat ca
# kamenka ru
# bredasdorp za
# luderitz na
# vaini to
# iqaluit ca
# tasiilaq gl
# atuona pf
# ushuaia ar
# hobart au
# rikitea pf
# opuwo na
# altay cn
# avera pf
# kapaa us
# east london za
# nome us
# ushuaia ar
# provideniya ru
# new norfolk au
# khatanga ru
# pevek ru
# broome au
# cabo san lucas mx
# bilibino ru
# bambous virieux mu
# saint-francois gp
# rikitea pf
# butaritari ki
# okhotsk ru
# rikitea pf
# pokhara np
# torbay ca
# kodiak us
# alyangula au
# hilo us
# barentsburg sj
# avarua ck
# aybak af
# hobart au
# rikitea pf
# matane ca
# hays us
# mys shmidta ru
# ponta do sol cv
# sidi ali dz
# butaritari ki
# walvis bay na
# la ronge ca
# pasighat in
# sayyan ye
# tsihombe mg
# albany au
# mitu co
# szczecinek pl
# sola vu
# thompson ca
# torbay ca
# saint-philippe re
# sao joao da barra br
# jamestown sh
# victoria sc
# punta arenas cl
# shakawe bw
# botwood ca
# ola ru
# busselton au
# castro cl
# noumea nc
# lagoa pt
# mala pe
# punta arenas cl
# mount isa au
# toftir fo
# ladysmith ca
# lompoc us
# esperance au
# taolanaro mg
# kapaa us
# gouyave gd
# mataura pf
# presidente medici br
# gladstone au
# rikitea pf
# chuy uy
# vaini to
# carnarvon au
# kulhudhuffushi mv
# kodiak us
# taolanaro mg
# pevek ru
# kolpny ru
# ushuaia ar
# east london za
# bredasdorp za
# praia da vitoria pt
# hilo us
# east london za
# nantucket us
# shelburne ca
# luderitz na
# shwebo mm
# hasaki jp
# punta arenas cl
# vaini to
# thompson ca
# norman wells ca
# lagos pt
# choma zm
# grand gaube mu
# buraydah sa
# thompson ca
# bara sd
# butaritari ki
# hervey bay au
# mumford gh
# barrow us
# dingle ie
# bredasdorp za
# camacha pt
# paamiut gl
# busselton au
# marrakesh ma
# esperance au
# vaitupu wf
# kuloy ru
# ushuaia ar
# cape town za
# rungata ki
# sao joao da barra br
# bure et
# mar del plata ar
# jizan sa
# atikokan ca
# busselton au
# rikitea pf
# port alfred za
# ushuaia ar
# samusu ws
# maltahohe na
# jamestown sh
# pevek ru
# kapaa us
# port lincoln au
# puerto ayora ec
# khatanga ru
# kaeng khlo th
# hermanus za
# rikitea pf
# barentsburg sj
# ponta delgada pt
# kapaa us
# la ronge ca
# butaritari ki
# buzmeyin tm
# mount pleasant us
# taolanaro mg
# fortuna us
# rikitea pf
# albany au
# loudi cn
# hobart au
# muzhi ru
# longyearbyen sj
# coquimbo cl
# kapaa us
# new norfolk au
# saint george bm
# charters towers au
# rikitea pf
# qui nhon vn
# punta arenas cl
# rincon an
# zonguldak tr
# kapaa us
# ushuaia ar
# avarua ck
# mataura pf
# rikitea pf
# khairagarh in
# ponta do sol cv
# saskylakh ru
# dickinson us
# kavieng pg
# kaeo nz
# chase ca
# carnarvon au
# hobart au
# punta arenas cl
# avarua ck
# ambilobe mg
# chakwal pk
# port arthur us
# taolanaro mg
# vila do maio cv
# nikolskoye ru
# belen us
# dikson ru
# mount isa au
# hermanus za
# tura ru
# ushuaia ar
# illoqqortoormiut gl
# busselton au
# ancud cl
# port alfred za
# bulolo pg
# lahaina us
# busselton au
# torbay ca
# rikitea pf
# gamboula cf
# ushuaia ar
# acajutla sv
# darfo it
# belushya guba ru
# petropavlovsk-kamchatskiy ru
# illoqqortoormiut gl
# champerico gt
# puerto ayora ec
# saint-michel-des-saints ca
# mataura pf
# carnarvon au
# rikitea pf
# kodiak us
# jamestown sh
# porto novo cv
# kapaa us
# cape town za
# tanggulangin id
# mahebourg mu
# omsukchan ru
# iqaluit ca
# thompson ca
# hermanus za
# saldanha za
# upernavik gl
# thompson ca
# qaanaaq gl
# southbridge nz
# amderma ru
# orlik ru
# puerto ayora ec
# tres lagoas br
# busselton au
# ushuaia ar
# tondano id
# port lincoln au
# butaritari ki
# qaanaaq gl
# anderson us
# kodiak us
# hilo us
# punta arenas cl
# tuy hoa vn
# upernavik gl
# chokurdakh ru
# lompoc us
# kapaa us
# georgetown sh
# barrow us
# bredy ru
# saint-philippe re
# ketchikan us
# mapiripan co
# yellowknife ca
# horasan tr
# hudson bay ca
# faanui pf
# mataura pf
# brae gb
# sao joao da barra br
# liverpool ca
# ancud cl
# salalah om
# kavieng pg
# mar del plata ar
# khatanga ru
# aguimes es
# kavaratti in
# illoqqortoormiut gl
# isilkul ru
# palabuhanratu id
# hithadhoo mv
# thompson ca
# likasi cd
# ruthin gb
# thompson ca
# avarua ck
# arraial do cabo br
# mataura pf
# chuy uy
# rikitea pf
# meulaboh id
# kapaa us
# yellowknife ca
# bredasdorp za
# albany au
# kahului us
# ushuaia ar
# limbe cm
# kapaa us
# cazaje ao
# kodiak us
# tuktoyaktuk ca
# yar-sale ru
# bethel us
# avarua ck
# paita pe
# cape town za
# rikitea pf
# la ronge ca
# maine-soroa ne
# qaqortoq gl
# bredasdorp za
# prattville us
# sao filipe cv
# rikitea pf
# georgetown sh
# amahai id
# port-gentil ga
# attawapiskat ca
# katsuura jp
# atuona pf
# mataura pf
# hithadhoo mv
# vostok ru
# luderitz na
# busselton au
# mys shmidta ru
# namibe ao
# albany au
# clyde river ca
# tasiilaq gl
# provideniya ru
# punta arenas cl
# taolanaro mg
# albany au
# hobart au
# port blair in
# dois vizinhos br
# mataura pf
# ushuaia ar
# qaanaaq gl
# sabzevar ir
# valenca br
# albany au
# prabumulih id
# rocha uy
# thompson ca
# victoria sc
# yellowknife ca
# vaini to
# forest hills us
# korla cn
# manacapuru br
# hermanus za
# yellowknife ca
# pandan ph
# kathu th
# hobart au
# lumeje ao
# ust-uda ru
# samusu ws
# mataura pf
# te anau nz
# armacao dos buzios br
# valdivia cl
# grand gaube mu
# mataura pf
# tasiilaq gl
# buzdyak ru
# nizhneyansk ru
# bredasdorp za
# vestmannaeyjar is
# thunder bay ca
# rikitea pf
# spring valley us
# rikitea pf
# barrow us
# rustenburg za
# krasnoarmeysk kz
# caravelas br
# vaini to
# new norfolk au
# lagoa pt
# busselton au
# katsuura jp
# rikitea pf
# hermanus za
# busselton au
# namatanai pg
# carmunnock gb
# atar mr
# norman wells ca
# illoqqortoormiut gl
# hilo us
# khatanga ru
# clyde river ca
# hermanus za
# trincomalee lk
# mataura pf
# pyaozerskiy ru
# san patricio mx
# taolanaro mg
# luderitz na
# bubaque gw
# georgetown sh
# ushuaia ar
# barranca pe
# sao miguel do araguaia br
# yialos gr
# yumen cn
# tuktoyaktuk ca
# busselton au
# chicama pe
# rikitea pf
# mataura pf
# albany au
# butaritari ki
# bluff nz
# novyy urgal ru
# castro cl
# araouane ml
# chuy uy
# roald no
# haines junction ca
# narva-joesuu ee
# atuona pf
# hobart au
# ponta do sol cv
# georgetown sh
# puerto ayora ec
# ushuaia ar
# mar del plata ar
# hilo us
# torbay ca
# makakilo city us
# ushuaia ar
# busselton au
# qaanaaq gl
# punta arenas cl
# arraial do cabo br
# flin flon ca
# jawhar so
# rikitea pf
# samusu ws
# longyearbyen sj
# tasiilaq gl
# saint-philippe re
# plettenberg bay za
# arica cl
# vila velha br
# souillac mu
# te anau nz
# tenenkou ml
# hualmay pe
# mataura pf
# bella union uy
# port alfred za
# namibe ao
# nagato jp
# santa lucia es
# banda aceh id
# tanabe jp
# oum hadjer td
# ushuaia ar
# hithadhoo mv
# ahipara nz
# dunedin nz
# yulara au
# saskylakh ru
# ushuaia ar
# ribeira grande pt
# pevek ru
# harper lr
# constitucion mx
# lagoa pt
# barrow us
# wanaka nz
# mataura pf
# cape town za
# rikitea pf
# chuy uy
# norman wells ca
# ribeira grande pt
# soller es
# airai pw
# albany au
# punta arenas cl
# srednekolymsk ru
# vaini to
# sao joao da barra br
# longyearbyen sj
# gidam in
# klaksvik fo
# vao nc
# hobart au
# ternate id
# vestmannaeyjar is
# kafyr-kumukh ru
# esperance au
# ostrovnoy ru
# treinta y tres uy
# teeli ru
# jamestown sh
# punta arenas cl
# vila vu
# lavrentiya ru
# tura ru
# thompson ca
# hithadhoo mv
# punta arenas cl
# albany au
# bluff nz
# cidreira br
# jamestown sh
# mitsamiouli km
# atuona pf
# kayerkan ru
# longyearbyen sj
# atuona pf
# broken hill au
# barentsburg sj
# bluff nz
# san carlos de bariloche ar
# atar mr
# arraial do cabo br
# cockburn town tc
# cape town za
# kaeo nz
# linden gy
# flinders au
# busselton au
# puerto ayora ec
# bredasdorp za
# khatanga ru
# saleaula ws
# taolanaro mg
# tuktoyaktuk ca
# svetlyy ru
# vaini to
# iqaluit ca
# izhma ru
# georgetown sh
# albany au
# hamilton bm
# busselton au
# harper lr
# avarua ck
# geraldton au
# busselton au
# hay river ca
# bambous virieux mu
# saint-philippe re
# hobart au
# amarante do maranhao br
# kadykchan ru
# punta arenas cl
# bluff nz
# raton us
# saskylakh ru
# arraial do cabo br
# kavaratti in
# kaitangata nz
# tasiilaq gl
# hobart au
# taolanaro mg
# leningradskiy ru
# illoqqortoormiut gl
# carnarvon au
# castro cl
# mataura pf
# qaanaaq gl
# busselton au
# albany au
# yelizovo ru
# stryn no
# muros es
# chuy uy
# khatanga ru
# saldanha za
# new norfolk au
# fairbanks us
# albany au
# albany au
# saskylakh ru
# castro cl
# mataura pf
# bluff nz
# yuryev-polskiy ru
# albany au
# brae gb
# thompson ca
# pisco pe
# punta arenas cl
# avarua ck
# ushuaia ar
# vila franca do campo pt
# mys shmidta ru
# castro cl
# faanui pf
# airai pw
# kaitangata nz
# hobart au
# klaksvik fo
# saskylakh ru
# moerai pf
# ushuaia ar
# mahebourg mu
# cidreira br
# ushuaia ar
# pisco pe
# krasnoselkup ru
# hermanus za
# dikson ru
# lasa cn
# barra do garcas br
# nchelenge zm
# bambous virieux mu
# aguimes es
# darab ir
# iqaluit ca
# fort nelson ca
# anloga gh
# punta arenas cl
# hendrina za
# lorengau pg
# arraial do cabo br
# rikitea pf
# leningradskiy ru
# bengkulu id
# san patricio mx
# kapaa us
# ushuaia ar
# marsabit ke
# punta arenas cl
# punta arenas cl
# georgetown sh
# namatanai pg
# dunedin nz
# albany au
# severo-kurilsk ru
# saint anthony ca
# dingle ie
# batagay-alyta ru
# lorengau pg
# busselton au
# lucapa ao
# mosquera co
# atherton au
# cidreira br
# kaitangata nz
# broken hill au
# okahandja na
# lagoa pt
# khatanga ru
# thompson ca
# qaanaaq gl
# new norfolk au
# iquique cl
# taolanaro mg
# muros es
# urusha ru
# jamestown sh
# georgetown sh
# wolbrom pl
# pipar in
# bluff nz
# marienburg sr
# east london za
# hilo us
# tarakan id
# kendal id
# tadine nc
# vaini to
# baruun-urt mn
# belushya guba ru
# vaini to
# yerbogachen ru
# hobart au
# hobart au
# ushuaia ar
# vaini to
# hambantota lk
# vaini to
# saint-philippe re
# grand river south east mu
# mar del plata ar
# puerto ayora ec
# mahebourg mu
# viedma ar
# ushuaia ar
# albany au
# muros es
# oktyabrskiy ru
# komsomolskiy ru
# cape town za
# upernavik gl
# yar-sale ru
# nome us
# diu in
# saucillo mx
# ushuaia ar
# ushuaia ar
# bambous virieux mu
# tacoronte es
# nemuro jp
# hilo us
# longyearbyen sj
# mys shmidta ru
# tasiilaq gl
# illoqqortoormiut gl
# newport us
# along in
# avarua ck
# tiksi ru
# albany au
# albany au
# faanui pf
# mataura pf
# najran sa
# kaka tm
# khatanga ru
# port elizabeth za
# atuona pf
# sentyabrskiy ru
# klaksvik fo
# punta arenas cl
# ushuaia ar
# pestovo ru
# saint-augustin ca
# kruisfontein za
# attawapiskat ca
# lebu cl
# norwich gb
# taolanaro mg
# fare pf
# bilma ne
# san quintin mx
# wageningen sr
# taolanaro mg
# sukumo jp
# busselton au
# batagay ru
# busselton au
# khatanga ru
# rikitea pf
# hobart au
# chincha alta pe
# salalah om
# mataura pf
# kapaa us
# ushuaia ar
# east london za
# carnarvon au
# nueva imperial cl
# ponta do sol cv
# hilo us
# itacare br
# peru us
# klaksvik fo
# inuvik ca
# rikitea pf
# hobart au
# busselton au
# rikitea pf
# ambunti pg
# gao ml
# bambous virieux mu
# saint anthony ca
# pevek ru
# belushya guba ru
# port alfred za
# albany au
# rikitea pf
# san buenaventura mx
# mahebourg mu
# mataura pf
# east london za
# uulu ee
# tsihombe mg
# praia da vitoria pt
# castro cl
# upernavik gl
# bluff nz
# luderitz na
# atuona pf
# attawapiskat ca
# beidao cn
# qaanaaq gl
# kruisfontein za
# comodoro rivadavia ar
# thompson ca
# rikitea pf
# busselton au
# illoqqortoormiut gl
# port alfred za
# port elizabeth za
# jinchengjiang cn
# vaitupu wf
# jamestown sh
# san juan ar
# mar del plata ar
# castro cl
# vardo no
# mataura pf
# east london za
# tapikan ph
# taolanaro mg
# rikitea pf
# morant bay jm
# kautokeino no
# kodiak us
# vaini to
# busselton au
# hermanus za
# mar del plata ar
# juifang tw
# tual id
# grand river south east mu
# flinders au
# aykhal ru
# blagoveshchenka ru
# klaksvik fo
# airai pw
# hermanus za
# illapel cl
# belushya guba ru
# jieshi cn
# provideniya ru
# zhanaozen kz
# tuktoyaktuk ca
# katsuura jp
# rikitea pf
# vaini to
# la ronge ca
# vila franca do campo pt
# labuhan id
# edson ca
# kapaa us
# melfort ca
# hilo us
# rikitea pf
# chokurdakh ru
# krasnoyarka ru
# bluff nz
# port alfred za
# nuuk gl
# eldikan ru
# bredasdorp za
# nuuk gl
# longyearbyen sj
# lixourion gr
# yenagoa ng
# attawapiskat ca
# rio grande br
# khatanga ru
# kaitangata nz
# severnyy-kospashskiy ru
# castro cl
# severo-kurilsk ru
# nikolskoye ru
# biak id
# bandarbeyla so
# tera ne
# ilulissat gl
# sao lourenco do sul br
# sentyabrskiy ru
# port alfred za
# kapaa us
# bahadurgarh in
# esperance au
# dikson ru
# saint george bm
# gulu ug
# ola ru
# busselton au
# malangali tz
# paita pe
# bredasdorp za
# new bern us
# castro cl
# gainesville us
# mabamba tz
# dalby au
# tasiilaq gl
# atuona pf
# busselton au
# ushuaia ar
# saskylakh ru
# parrita cr
# victor harbor au
# marsa matruh eg
# yellowknife ca
# kaitangata nz
# mendi et
# yellowknife ca
# saint-pierre pm
# avarua ck
# komsomolskiy ru
# dutlwe bw
# tuktoyaktuk ca
# taltal cl
# monrovia lr
# rikitea pf
# avarua ck
# tiksi ru
# fortuna us
# cukai my
# ushuaia ar
# kapaa us
# areia branca br
# el wasta eg
# ust-maya ru
# kodiak us
# maldonado uy
# pevek ru
# busselton au
# otavi na
# taolanaro mg
# punta arenas cl
# khor qa
# honiara sb
# tiksi ru
# salalah om
# rikitea pf
# belushya guba ru
# tsihombe mg
# bintulu my
# atuona pf
# puerto ayora ec
# tromso no
# aklavik ca
# hithadhoo mv
# kautokeino no
# vaini to
# ushuaia ar
# chushan tw
# cidreira br
# ushuaia ar
# kamenskoye ru
# constitucion cl
# saldanha za
# faanui pf
# arraial do cabo br
# verkhoyansk ru
# georgetown sh
# bluff nz
# asau tv
# berbera so
# new norfolk au
# thompson ca
# tautira pf
# tsihombe mg
# butaritari ki
# hofn is
# mys shmidta ru
# georgetown sh
# davila ph
# watsa cd
# hasaki jp
# hobart au
# erenhot cn
# ushuaia ar
# hermanus za
# san quintin mx
# merrill us
# punta arenas cl
# altar mx
# ostrovnoy ru
# carnarvon au
# butaritari ki
# port hedland au
# markova ru
# bredasdorp za
# terrace ca
# plettenberg bay za
# mananjary mg
# albany au
# tiksi ru
# tiksi ru
# hermanus za
# jamestown sh
# chaozhou cn
# belushya guba ru
# ilebo cd
# dakar sn
# yellowknife ca
# kimry ru
# qaanaaq gl
# torbay ca
# kuche cn
# khatanga ru
# cape town za
# hobart au
# rikitea pf
# hamilton bm
# butaritari ki
# georgetown sh
# tepeojuma mx
# albany au
# port elizabeth za
# albany au
# hunza pk
# marawi sd
# asyut eg
# kapaa us
# te anau nz
# san ramon bo
# hervey bay au
# luderitz na
# vaini to
# cape town za
# san patricio mx
# kodiak us
# thompson ca
# faya td
# luanda ao
# new norfolk au
# mys shmidta ru
# scarborough gb
# ushuaia ar
# butaritari ki
# marica br
# goulburn au
# lucea jm
# nicoya cr
# port alfred za
# atuona pf
# sierra vista us
# belushya guba ru
# taolanaro mg
# hithadhoo mv
# busselton au
# mataura pf
# busselton au
# houma us
# tiksi ru
# bandarbeyla so
# rikitea pf
# papillion us
# albany au
# vaitape pf
# klaksvik fo
# tianmen cn
# port alfred za
# kapaa us
# hermanus za
# acajutla sv
# bubaque gw
# tuktoyaktuk ca
# horqueta py
# saint-joseph re
# sentyabrskiy ru
# ushuaia ar
# nuziders at
# mount gambier au
# hobart au
# puerto carreno co
# atuona pf
# sentyabrskiy ru
# busselton au
# busselton au
# iracoubo gf
# egvekinot ru
# hobart au
# oistins bb
# qaanaaq gl
# khatanga ru
# east london za
# busselton au
# liwale tz
# khatanga ru
# cayenne gf
# illoqqortoormiut gl
# punta arenas cl
# hobart au
# porto santo pt
# vaini to
# lebu cl
# beringovskiy ru
# ushuaia ar
# ponta do sol cv
# husavik is
# camopi gf
# la libertad gt
# atuona pf
# puerto ayora ec
# illoqqortoormiut gl
# busselton au
# cape town za
# ushuaia ar
# kozhva ru
# vengurla in
# rikitea pf
# levski bg
# taolanaro mg
# illoqqortoormiut gl
# victoria sc
# ushuaia ar
# ushuaia ar
# qaanaaq gl
# camana pe
# verkhoyansk ru
# sao filipe cv
# east london za
# ponta do sol cv
# tsihombe mg
# hermanus za
# bredasdorp za
# dinguiraye gn
# rikitea pf
# maceio br
# albany au
# ushuaia ar
# hermanus za
# port hedland au
# severo-kurilsk ru
# bluff nz
# avarua ck
# rawson ar
# bredasdorp za
# albany au
# albany au
# hobart au
# bathsheba bb
# yumen cn
# varghis ro
# paamiut gl
# tasiilaq gl
# busselton au
# pandan ph
# novoye leushino ru
# wajima jp
# atuona pf
# taolanaro mg
# vaini to
# mar del plata ar
# mar del plata ar
# husavik is
# beli manastir hr
# hermanus za
# puerto ayora ec
# ushuaia ar
# saint-philippe re
# kodiak us
# hermanus za
# ushuaia ar
# chegdomyn ru
# albany au
# havre-saint-pierre ca
# albany au
# tuktoyaktuk ca
# dikson ru
# hasaki jp
# rikitea pf
# samalaeulu ws
# teabo mx
# cocobeach ga
# baykit ru
# yeniseysk ru
# qaanaaq gl
# kudahuvadhoo mv
# taolanaro mg
# zyryanovsk kz
# saskylakh ru
# rognan no
# port alfred za
# ust-kulom ru
# punta arenas cl
# fairbanks us
# cherskiy ru
# catuday ph
# albany au
# chuy uy
# grand gaube mu
# busselton au
# vagur fo
# saskylakh ru
# primorsk ru
# khorramshahr ir
# rikitea pf
# mataura pf
# bethel us
# doctor arroyo mx
# maceio br
# codrington ag
# atuona pf
# rikitea pf
# puerto carreno co
# nikolskoye ru
# hermanus za
# rikitea pf
# ilulissat gl
# victoria sc
# dikson ru
# ushuaia ar
# biltine td
# paredon mx
# rikitea pf
# auki sb
# douentza ml
# batagay-alyta ru
# alness gb
# jamestown sh
# keffi ng
# kaitangata nz
# vardo no
# busselton au
# saint-philippe re
# nishihara jp
# ushuaia ar
# arraial do cabo br
# ushuaia ar
# mackenzie ca
# nanortalik gl
# pisco pe
# severo-kurilsk ru
# ribeira grande pt
# seoul kr
# vanimo pg
# avarua ck
# ushuaia ar
# vao nc
# vestmannaeyjar is
# severo-kurilsk ru
# butaritari ki
# tuktoyaktuk ca
# puerto ayora ec
# dingle ie
# pouebo nc
# bredasdorp za
# haverfordwest gb
# san vicente ph
# ushuaia ar
# punta arenas cl
# atuona pf
# mahebourg mu
# jamestown sh
# atuona pf
# qaqortoq gl
# yellowknife ca
# mys shmidta ru
# mataura pf
# arraial do cabo br
# jamestown sh
# pangnirtung ca
# abu kamal sy
# tasiilaq gl
# toftir fo
# dicabisagan ph
# illoqqortoormiut gl
# halalo wf
# busselton au
# bengkulu id
# sapulpa us
# dikson ru
# maragogi br
# saint-philippe re
# kodiak us
# yulara au
# ushuaia ar
# kodiak us
# torbay ca
# port alfred za
# saskylakh ru
# westport ie
# barrow us
# albany au
# ushuaia ar
# puerto ayora ec
# cabo san lucas mx
# kungurtug ru
# ilulissat gl
# ambilobe mg
# port alfred za
# vaini to
# marcona pe
# severo-kurilsk ru
# sahrak af
# goksun tr
# qaqortoq gl
# sovetskaya gavan ru
# yeppoon au
# mataura pf
# barrow us
# torbay ca
# punta arenas cl
# maneadero mx
# aklavik ca
# hermanus za
# lahij ye
# ushuaia ar
# yellowknife ca
# hilo us
# ushuaia ar
# punta arenas cl
# mataura pf
# belushya guba ru
# torbay ca
# busselton au
# killybegs ie
# taltal cl
# tuktoyaktuk ca
# hamilton bm
# sitka us
# muravlenko ru
# victoria sc
# beloha mg
# sur om
# chuy uy
# mys shmidta ru
# new norfolk au
# barrow us
# saint-philippe re
# solenzo bf
# barrow us
# hilo us
# mandalgovi mn
# rikitea pf
# puerto ayora ec
# arraial do cabo br
# dikson ru
# talnakh ru
# albany au
# rikitea pf
# new norfolk au
# mahebourg mu
# hermanus za
# new norfolk au
# bellmead us
# airai pw
# ballangen no
# ribeira grande pt
# esperance au
# elko us
# busselton au
# jega ng
# nha trang vn
# vaini to
# bulolo pg
# hami cn
# mosquera co
# barrow us
# carnarvon au
# ajdabiya ly
# pakokku mm
# cockburn town tc
# taolanaro mg
# cayenne gf
# sabang id
# samarai pg
# nalobikha ru
# vaitupu wf
# rikitea pf
# yellowknife ca
# katangli ru
# najran sa
# palmer us
# nizhneyansk ru
# roma au
# pisco pe
# busselton au
# rikitea pf
# ribeira do pombal br
# chokurdakh ru
# nola cf
# quesnel ca
# thompson ca
# mar del plata ar
# ushuaia ar
# taolanaro mg
# ushuaia ar
# quatre cocos mu
# georgetown sh
# fort nelson ca
# mataura pf
# tevaitoa pf
# luderitz na
# illoqqortoormiut gl
# los llanos de aridane es
# taolanaro mg
# mount gambier au
# ushuaia ar
# busselton au
# mataura pf
# lagoa pt
# busselton au
# cape town za
# vaini to
# labrea br
# hithadhoo mv
# hobart au
# korcula hr
# tiksi ru
# butaritari ki
# barentsburg sj
# ushuaia ar
# kuching my
# broken hill au
# mahebourg mu
# kodiak us
# paranaiba br
# broome au
# thompson ca
# birakan ru
# castro cl
# nome us
# ribeira grande pt
# pangnirtung ca
# hermanus za
# cherskiy ru
# gabu gw
# clyde river ca
# solnechnyy ru
# mahebourg mu
# ushuaia ar
# ketchikan us
# chokurdakh ru
# mogadishu so
# novyy buh ua
# vitim ru
# victoria sc
# novaya igirma ru
# abu samrah qa
# turtkul uz
# puerto escondido mx
# rikitea pf
# jalu ly
# hilo us
# thunder bay ca
# bardiyah ly
# punta arenas cl
# saint-denis re
# nanortalik gl
# port alfred za
# deputatskiy ru
# santa vitoria do palmar br
# hermanus za
# derzhavinsk kz
# barentsburg sj
# rikitea pf
# avera pf
# bluff nz
# punta arenas cl
# klaksvik fo
# atuona pf
# colares pt
# castro cl
# podor sn
# illoqqortoormiut gl
# bluff nz
# busselton au
# lebu cl
# puerto leguizamo co
# punta arenas cl
# nantucket us
# attawapiskat ca
# belmonte br
# taolanaro mg
# australind au
# cordoba ar
# mataura pf
# kirensk ru
# illoqqortoormiut gl
# klaksvik fo
# dalaba gn
# hay river ca
# tuktoyaktuk ca
# biak id
# qaanaaq gl
# high level ca
# tiksi ru
# itubera br
# atuona pf
# dubrovytsya ua
# kyabe td
# torbay ca
# asgabat tm
# taolanaro mg
# namatanai pg
# yellowknife ca
# karaul ru
# busselton au
# constitucion mx
# saurimo ao
# tura ru
# illoqqortoormiut gl
# aksu kz
# rawson ar
# mataura pf
# souillac mu
# rosetta eg
# rikitea pf
# tuktoyaktuk ca
# hobart au
# taolanaro mg
# ushuaia ar
# port hedland au
# saint-philippe re
# lata sb
# yerbogachen ru
# mlonggo id
# new norfolk au
# rikitea pf
# palmerston north nz
# banihal in
# celestun mx
# belushya guba ru
# qaanaaq gl
# busselton au
# abaetetuba br
# ushuaia ar
# tiksi ru
# palabuhanratu id
# jamestown sh
# te anau nz
# barrow us
# san ramon bo
# fortuna us
# goderich sl
# puerto ayora ec
# puerto ayora ec
# tunxi cn
# new norfolk au
# carnarvon au
# hobart au
# bambous virieux mu
# andra ru
# rikitea pf
# hithadhoo mv
# hobart au
# hermanus za
# kapaa us
# rikitea pf
# albury au
# castro cl
# busselton au
# leningradskiy ru
# tsabong bw
# bluff nz
# sakakah sa
# puerto ayora ec
# hithadhoo mv
# geraldton au
# pyu mm
# kofele et
# avarua ck
# saskylakh ru
# lebu cl
# ihtiman bg
# albany au
# tuatapere nz
# phan rang vn
# bengkulu id
# cabo san lucas mx
# new norfolk au
# severo-kurilsk ru
# la roda es
# puerto ayora ec
# saint-joseph re
# codrington ag
# rikitea pf
# yellowknife ca
# narsaq gl
# saint-philippe re
# rikitea pf
# severomuysk ru
# cidreira br
# castro cl
# hilo us
# yellowknife ca
# puerto ayora ec
# atuona pf
# kuche cn
# cape town za
# matamoros mx
# tasiilaq gl
# porto murtinho br
# benghazi ly
# isangel vu
# kizukuri jp
# sideropolis br
# kirakira sb
# barentsburg sj
# mar del plata ar
# punta arenas cl
# rikitea pf
# qaqortoq gl
# narsaq gl
# nguiu au
# ushuaia ar
# vao nc
# yellowknife ca
# rikitea pf
# whitianga nz
# butaritari ki
# sioux lookout ca
# sistranda no
# tuggurt dz
# avarua ck
# hilo us
# east london za
# kampene cd
# hualmay pe
# chaiya th
# vanimo pg
# borogontsy ru
# jamestown sh
# hovd mn
# novodugino ru
# cape town za
# koboldo ru
# tiarei pf
# gap fr
# ola ru
# aasiaat gl
# taolanaro mg
# provideniya ru
# hermanus za
# namibe ao
# arraial do cabo br
# ushuaia ar
# ushuaia ar
# yamada jp
# port alfred za
# punta arenas cl
# cabo san lucas mx
# qasigiannguit gl
# bambous virieux mu
# manavgat tr
# hasaki jp
# cape town za
# salinopolis br
# hope ca
# celestun mx
# ponta do sol cv
# cabo san lucas mx
# coquimbo cl
# bredasdorp za
# chokurdakh ru
# mataura pf
# inongo cd
# punta arenas cl
# mataura pf
# albany au
# hermanus za
# kot diji pk
# bethel us
# punta arenas cl
# georgetown sh
# busselton au
# lata sb
# elko us
# yellowknife ca
# tuktoyaktuk ca
# nowy targ pl
# bluff nz
# barrow us
# cape town za
# belushya guba ru
# lakatoro vu
# jamestown sh
# punta arenas cl
# vila franca do campo pt
# along in
# qaanaaq gl
# tasiilaq gl
# victoria sc
# ancona it
# rikitea pf
# hamada jp
# ushuaia ar
# nome us
# asfi ma
# kaeo nz
# atuona pf
# albany au
# ushuaia ar
# hilo us
# araouane ml
# provideniya ru
# georgetown sh
# atuona pf
# parainen fi
# toulepleu ci
# ushuaia ar
# ushuaia ar
# puerto ayora ec
# donji milanovac rs
# cape town za
# busselton au
# busselton au
# loganville us
# puerto ayora ec
# bismarck us
# arraial do cabo br
# tasiilaq gl
# sentyabrskiy ru
# attawapiskat ca
# ijaki ki
# port blair in
# saldanha za
# port alfred za
# kabare cd
# antofagasta cl
# port alfred za
# ushuaia ar
# port hardy ca
# jamestown sh
# vaitupu wf
# sudak ua
# bure et
# castro cl
# punta arenas cl
# nguiu au
# south lake tahoe us
# chokurdakh ru
# rikitea pf
# la aldea mx
# vaini to
# kamaishi jp
# rikitea pf
# cape town za
# taolanaro mg
# marsabit ke
# mataura pf
# saleaula ws
# alofi nu
# castro cl
# mataura pf
# touros br
# nesna no
# bluff nz
# shingu jp
# atuona pf
# sitka us
# bilibino ru
# nargana pa
# khatanga ru
# necochea ar
# hirara jp
# sao filipe cv
# padang id
# flinders au
# wau pg
# bluff nz
# kodiak us
# bluff nz
# qaanaaq gl
# puerto ayora ec
# lahij ye
# mazamari pe
# rikitea pf
# busselton au
# jamestown sh
# constitucion mx
# mahebourg mu
# punta arenas cl
# rikitea pf
# ancud cl
# lavrentiya ru
# illoqqortoormiut gl
# kodiak us
# busselton au
# souillac mu
# changji cn

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 721

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-" * 25)

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        #Append the city information into city_data
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-" * 25)
print("Data Retrieval Complete")
print("-" * 25)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | comodoro rivadavia
# Processing Record 3 of Set 1 | chokurdakh
# Processing Record 4 of Set 1 | mar del plata
# Processing Record 5 of Set 1 | arraial do cabo
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | broome
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | hasaki
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | marquette
# Processing Record 13 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 1 | torbay
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | krasnyy yar
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 1 | waingapu
# Processing Record 20 of Set 1 | saskylakh
# Processing Record 21 of Set 1 | hithadhoo
# Processing Record 22 of Set 1 | charters towers
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | maumere
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | vuktyl
# Processing Record 28 of Set 1 | ahipara
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | abeche
# Processing Record 32 of Set 1 | bengkulu
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | lagoa
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | saint-joseph
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | lompoc
# Processing Record 41 of Set 1 | coquimbo
# Processing Record 42 of Set 1 | new norfolk
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | kruisfontein
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | rosarito
# Processing Record 47 of Set 1 | kolosovka
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | korla
# Processing Record 50 of Set 1 | lorengau
# Processing Record 1 of Set 2 | cidreira
# Processing Record 2 of Set 2 | karaton
# Processing Record 3 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 2 | fernley
# Processing Record 5 of Set 2 | sembabule
# Processing Record 6 of Set 2 | qaqortoq
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | cherskiy
# Processing Record 9 of Set 2 | porto santo
# Processing Record 10 of Set 2 | ihtiman
# Processing Record 11 of Set 2 | zhigansk
# Processing Record 12 of Set 2 | labuhan
# Processing Record 13 of Set 2 | saint george
# Processing Record 14 of Set 2 | lebu
# Processing Record 15 of Set 2 | saldanha
# Processing Record 16 of Set 2 | ekibastuz
# Processing Record 17 of Set 2 | san cristobal
# Processing Record 18 of Set 2 | kodiak
# Processing Record 19 of Set 2 | ostrovnoy
# Processing Record 20 of Set 2 | tuktoyaktuk
# Processing Record 21 of Set 2 | qaanaaq
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | stepnyak
# Processing Record 25 of Set 2 | pevek
# Processing Record 26 of Set 2 | whitecourt
# Processing Record 27 of Set 2 | bandarbeyla
# Processing Record 28 of Set 2 | castro
# Processing Record 29 of Set 2 | qui nhon
# Processing Record 30 of Set 2 | kaitangata
# Processing Record 31 of Set 2 | fairbanks
# Processing Record 32 of Set 2 | goderich
# Processing Record 33 of Set 2 | sao pedro
# Processing Record 34 of Set 2 | tabou
# Processing Record 35 of Set 2 | bubaque
# Processing Record 36 of Set 2 | bathsheba
# Processing Record 37 of Set 2 | port hedland
# Processing Record 38 of Set 2 | atuona
# Processing Record 39 of Set 2 | bethel
# Processing Record 40 of Set 2 | kahramanmaras
# Processing Record 41 of Set 2 | sitka
# Processing Record 42 of Set 2 | zeya
# Processing Record 43 of Set 2 | arlit
# Processing Record 44 of Set 2 | batagay
# Processing Record 45 of Set 2 | klaksvik
# Processing Record 46 of Set 2 | pittsburg
# Processing Record 47 of Set 2 | takoradi
# Processing Record 48 of Set 2 | lakes entrance
# Processing Record 49 of Set 2 | puruliya
# Processing Record 50 of Set 2 | khatanga
# Processing Record 1 of Set 3 | nacozari
# Processing Record 2 of Set 3 | cockburn town
# Processing Record 3 of Set 3 | guilin
# Processing Record 4 of Set 3 | mataura
# Processing Record 5 of Set 3 | katsuura
# Processing Record 6 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | tubuala
# Processing Record 8 of Set 3 | itarema
# Processing Record 9 of Set 3 | hovd
# Processing Record 10 of Set 3 | whitianga
# Processing Record 11 of Set 3 | abu kamal
# Processing Record 12 of Set 3 | mahebourg
# Processing Record 13 of Set 3 | ksenyevka
# City not found. Skipping...
# Processing Record 14 of Set 3 | codrington
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | tawnat
# City not found. Skipping...
# Processing Record 17 of Set 3 | cap malheureux
# Processing Record 18 of Set 3 | mazamari
# Processing Record 19 of Set 3 | hobart
# Processing Record 20 of Set 3 | boali
# Processing Record 21 of Set 3 | port pirie
# Processing Record 22 of Set 3 | avarua
# Processing Record 23 of Set 3 | vaini
# Processing Record 24 of Set 3 | muyezerskiy
# Processing Record 25 of Set 3 | kavieng
# Processing Record 26 of Set 3 | mugur-aksy
# Processing Record 27 of Set 3 | kapoeta
# Processing Record 28 of Set 3 | east london
# Processing Record 29 of Set 3 | baruun-urt
# Processing Record 30 of Set 3 | chernyshevskiy
# Processing Record 31 of Set 3 | mafinga
# Processing Record 32 of Set 3 | svetlogorsk
# Processing Record 33 of Set 3 | kloulklubed
# Processing Record 34 of Set 3 | tezu
# Processing Record 35 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 3 | kamenka
# Processing Record 37 of Set 3 | luderitz
# Processing Record 38 of Set 3 | iqaluit
# Processing Record 39 of Set 3 | opuwo
# Processing Record 40 of Set 3 | altay
# Processing Record 41 of Set 3 | avera
# Processing Record 42 of Set 3 | kapaa
# Processing Record 43 of Set 3 | nome
# Processing Record 44 of Set 3 | cabo san lucas
# Processing Record 45 of Set 3 | bilibino
# Processing Record 46 of Set 3 | bambous virieux
# Processing Record 47 of Set 3 | saint-francois
# Processing Record 48 of Set 3 | okhotsk
# Processing Record 49 of Set 3 | pokhara
# Processing Record 50 of Set 3 | alyangula
# Processing Record 1 of Set 4 | aybak
# City not found. Skipping...
# Processing Record 2 of Set 4 | matane
# Processing Record 3 of Set 4 | hays
# Processing Record 4 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 4 | ponta do sol
# Processing Record 6 of Set 4 | sidi ali
# Processing Record 7 of Set 4 | walvis bay
# Processing Record 8 of Set 4 | la ronge
# Processing Record 9 of Set 4 | pasighat
# Processing Record 10 of Set 4 | sayyan
# Processing Record 11 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 4 | mitu
# Processing Record 13 of Set 4 | szczecinek
# Processing Record 14 of Set 4 | sola
# Processing Record 15 of Set 4 | thompson
# Processing Record 16 of Set 4 | sao joao da barra
# Processing Record 17 of Set 4 | victoria
# Processing Record 18 of Set 4 | shakawe
# Processing Record 19 of Set 4 | botwood
# Processing Record 20 of Set 4 | ola
# Processing Record 21 of Set 4 | noumea
# Processing Record 22 of Set 4 | mala
# Processing Record 23 of Set 4 | mount isa
# Processing Record 24 of Set 4 | toftir
# City not found. Skipping...
# Processing Record 25 of Set 4 | ladysmith
# Processing Record 26 of Set 4 | esperance
# Processing Record 27 of Set 4 | gouyave
# Processing Record 28 of Set 4 | presidente medici
# Processing Record 29 of Set 4 | gladstone
# Processing Record 30 of Set 4 | kulhudhuffushi
# Processing Record 31 of Set 4 | kolpny
# Processing Record 32 of Set 4 | praia da vitoria
# Processing Record 33 of Set 4 | nantucket
# Processing Record 34 of Set 4 | shelburne
# Processing Record 35 of Set 4 | shwebo
# Processing Record 36 of Set 4 | norman wells
# Processing Record 37 of Set 4 | lagos
# Processing Record 38 of Set 4 | choma
# Processing Record 39 of Set 4 | grand gaube
# Processing Record 40 of Set 4 | buraydah
# Processing Record 41 of Set 4 | bara
# Processing Record 42 of Set 4 | hervey bay
# Processing Record 43 of Set 4 | mumford
# Processing Record 44 of Set 4 | dingle
# Processing Record 45 of Set 4 | camacha
# Processing Record 46 of Set 4 | paamiut
# Processing Record 47 of Set 4 | marrakesh
# Processing Record 48 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 4 | kuloy
# Processing Record 50 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 5 | bure
# Processing Record 2 of Set 5 | jizan
# Processing Record 3 of Set 5 | atikokan
# Processing Record 4 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 5 | maltahohe
# Processing Record 6 of Set 5 | port lincoln
# Processing Record 7 of Set 5 | kaeng khlo
# City not found. Skipping...
# Processing Record 8 of Set 5 | ponta delgada
# Processing Record 9 of Set 5 | buzmeyin
# Processing Record 10 of Set 5 | mount pleasant
# Processing Record 11 of Set 5 | fortuna
# Processing Record 12 of Set 5 | loudi
# Processing Record 13 of Set 5 | muzhi
# Processing Record 14 of Set 5 | longyearbyen
# Processing Record 15 of Set 5 | rincon
# Processing Record 16 of Set 5 | zonguldak
# Processing Record 17 of Set 5 | khairagarh
# Processing Record 18 of Set 5 | dickinson
# Processing Record 19 of Set 5 | kaeo
# Processing Record 20 of Set 5 | chase
# Processing Record 21 of Set 5 | ambilobe
# Processing Record 22 of Set 5 | chakwal
# Processing Record 23 of Set 5 | port arthur
# Processing Record 24 of Set 5 | vila do maio
# Processing Record 25 of Set 5 | belen
# Processing Record 26 of Set 5 | dikson
# Processing Record 27 of Set 5 | tura
# Processing Record 28 of Set 5 | ancud
# Processing Record 29 of Set 5 | bulolo
# Processing Record 30 of Set 5 | lahaina
# Processing Record 31 of Set 5 | gamboula
# Processing Record 32 of Set 5 | acajutla
# Processing Record 33 of Set 5 | darfo
# Processing Record 34 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 5 | champerico
# Processing Record 36 of Set 5 | saint-michel-des-saints
# Processing Record 37 of Set 5 | porto novo
# Processing Record 38 of Set 5 | tanggulangin
# Processing Record 39 of Set 5 | omsukchan
# Processing Record 40 of Set 5 | upernavik
# Processing Record 41 of Set 5 | southbridge
# Processing Record 42 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 5 | orlik
# Processing Record 44 of Set 5 | tres lagoas
# Processing Record 45 of Set 5 | tondano
# Processing Record 46 of Set 5 | anderson
# Processing Record 47 of Set 5 | tuy hoa
# Processing Record 48 of Set 5 | georgetown
# Processing Record 49 of Set 5 | bredy
# Processing Record 50 of Set 5 | ketchikan
# Processing Record 1 of Set 6 | mapiripan
# Processing Record 2 of Set 6 | horasan
# Processing Record 3 of Set 6 | hudson bay
# Processing Record 4 of Set 6 | faanui
# Processing Record 5 of Set 6 | brae
# Processing Record 6 of Set 6 | liverpool
# Processing Record 7 of Set 6 | salalah
# Processing Record 8 of Set 6 | aguimes
# Processing Record 9 of Set 6 | kavaratti
# Processing Record 10 of Set 6 | isilkul
# Processing Record 11 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 6 | likasi
# Processing Record 13 of Set 6 | ruthin
# Processing Record 14 of Set 6 | meulaboh
# Processing Record 15 of Set 6 | kahului
# Processing Record 16 of Set 6 | limbe
# Processing Record 17 of Set 6 | cazaje
# City not found. Skipping...
# Processing Record 18 of Set 6 | yar-sale
# Processing Record 19 of Set 6 | paita
# Processing Record 20 of Set 6 | maine-soroa
# Processing Record 21 of Set 6 | prattville
# Processing Record 22 of Set 6 | sao filipe
# Processing Record 23 of Set 6 | amahai
# Processing Record 24 of Set 6 | port-gentil
# Processing Record 25 of Set 6 | vostok
# Processing Record 26 of Set 6 | namibe
# Processing Record 27 of Set 6 | clyde river
# Processing Record 28 of Set 6 | port blair
# Processing Record 29 of Set 6 | dois vizinhos
# Processing Record 30 of Set 6 | sabzevar
# Processing Record 31 of Set 6 | valenca
# Processing Record 32 of Set 6 | prabumulih
# Processing Record 33 of Set 6 | rocha
# Processing Record 34 of Set 6 | forest hills
# Processing Record 35 of Set 6 | manacapuru
# Processing Record 36 of Set 6 | pandan
# Processing Record 37 of Set 6 | kathu
# Processing Record 38 of Set 6 | lumeje
# Processing Record 39 of Set 6 | ust-uda
# Processing Record 40 of Set 6 | te anau
# Processing Record 41 of Set 6 | armacao dos buzios
# City not found. Skipping...
# Processing Record 42 of Set 6 | valdivia
# Processing Record 43 of Set 6 | buzdyak
# Processing Record 44 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 6 | vestmannaeyjar
# Processing Record 46 of Set 6 | thunder bay
# Processing Record 47 of Set 6 | spring valley
# Processing Record 48 of Set 6 | rustenburg
# Processing Record 49 of Set 6 | krasnoarmeysk
# Processing Record 50 of Set 6 | caravelas
# Processing Record 1 of Set 7 | namatanai
# Processing Record 2 of Set 7 | carmunnock
# Processing Record 3 of Set 7 | atar
# Processing Record 4 of Set 7 | trincomalee
# Processing Record 5 of Set 7 | pyaozerskiy
# Processing Record 6 of Set 7 | san patricio
# Processing Record 7 of Set 7 | barranca
# Processing Record 8 of Set 7 | sao miguel do araguaia
# Processing Record 9 of Set 7 | yialos
# City not found. Skipping...
# Processing Record 10 of Set 7 | yumen
# Processing Record 11 of Set 7 | chicama
# Processing Record 12 of Set 7 | novyy urgal
# Processing Record 13 of Set 7 | araouane
# Processing Record 14 of Set 7 | roald
# Processing Record 15 of Set 7 | haines junction
# Processing Record 16 of Set 7 | narva-joesuu
# Processing Record 17 of Set 7 | makakilo city
# Processing Record 18 of Set 7 | flin flon
# Processing Record 19 of Set 7 | jawhar
# Processing Record 20 of Set 7 | plettenberg bay
# Processing Record 21 of Set 7 | arica
# Processing Record 22 of Set 7 | vila velha
# Processing Record 23 of Set 7 | souillac
# Processing Record 24 of Set 7 | tenenkou
# Processing Record 25 of Set 7 | hualmay
# Processing Record 26 of Set 7 | bella union
# Processing Record 27 of Set 7 | nagato
# Processing Record 28 of Set 7 | santa lucia
# Processing Record 29 of Set 7 | banda aceh
# Processing Record 30 of Set 7 | tanabe
# Processing Record 31 of Set 7 | oum hadjer
# Processing Record 32 of Set 7 | dunedin
# Processing Record 33 of Set 7 | yulara
# Processing Record 34 of Set 7 | ribeira grande
# Processing Record 35 of Set 7 | harper
# Processing Record 36 of Set 7 | constitucion
# Processing Record 37 of Set 7 | wanaka
# Processing Record 38 of Set 7 | soller
# Processing Record 39 of Set 7 | airai
# Processing Record 40 of Set 7 | srednekolymsk
# Processing Record 41 of Set 7 | gidam
# Processing Record 42 of Set 7 | vao
# Processing Record 43 of Set 7 | ternate
# Processing Record 44 of Set 7 | kafyr-kumukh
# Processing Record 45 of Set 7 | treinta y tres
# Processing Record 46 of Set 7 | teeli
# Processing Record 47 of Set 7 | vila
# Processing Record 48 of Set 7 | lavrentiya
# Processing Record 49 of Set 7 | mitsamiouli
# Processing Record 50 of Set 7 | kayerkan
# Processing Record 1 of Set 8 | broken hill
# Processing Record 2 of Set 8 | san carlos de bariloche
# Processing Record 3 of Set 8 | linden
# Processing Record 4 of Set 8 | flinders
# Processing Record 5 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 8 | svetlyy
# Processing Record 7 of Set 8 | izhma
# Processing Record 8 of Set 8 | hamilton
# Processing Record 9 of Set 8 | geraldton
# Processing Record 10 of Set 8 | hay river
# Processing Record 11 of Set 8 | amarante do maranhao
# Processing Record 12 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 13 of Set 8 | raton
# Processing Record 14 of Set 8 | leningradskiy
# Processing Record 15 of Set 8 | yelizovo
# Processing Record 16 of Set 8 | stryn
# Processing Record 17 of Set 8 | muros
# Processing Record 18 of Set 8 | yuryev-polskiy
# Processing Record 19 of Set 8 | pisco
# Processing Record 20 of Set 8 | vila franca do campo
# Processing Record 21 of Set 8 | moerai
# Processing Record 22 of Set 8 | krasnoselkup
# Processing Record 23 of Set 8 | lasa
# Processing Record 24 of Set 8 | barra do garcas
# Processing Record 25 of Set 8 | nchelenge
# Processing Record 26 of Set 8 | darab
# Processing Record 27 of Set 8 | fort nelson
# Processing Record 28 of Set 8 | anloga
# Processing Record 29 of Set 8 | hendrina
# Processing Record 30 of Set 8 | marsabit
# Processing Record 31 of Set 8 | severo-kurilsk
# Processing Record 32 of Set 8 | saint anthony
# Processing Record 33 of Set 8 | batagay-alyta
# Processing Record 34 of Set 8 | lucapa
# Processing Record 35 of Set 8 | mosquera
# Processing Record 36 of Set 8 | atherton
# Processing Record 37 of Set 8 | okahandja
# Processing Record 38 of Set 8 | iquique
# Processing Record 39 of Set 8 | urusha
# Processing Record 40 of Set 8 | wolbrom
# Processing Record 41 of Set 8 | pipar
# Processing Record 42 of Set 8 | marienburg
# Processing Record 43 of Set 8 | tarakan
# Processing Record 44 of Set 8 | kendal
# Processing Record 45 of Set 8 | tadine
# Processing Record 46 of Set 8 | yerbogachen
# Processing Record 47 of Set 8 | hambantota
# Processing Record 48 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 8 | viedma
# Processing Record 50 of Set 8 | oktyabrskiy
# Processing Record 1 of Set 9 | komsomolskiy
# Processing Record 2 of Set 9 | diu
# Processing Record 3 of Set 9 | saucillo
# Processing Record 4 of Set 9 | tacoronte
# Processing Record 5 of Set 9 | nemuro
# Processing Record 6 of Set 9 | newport
# Processing Record 7 of Set 9 | along
# Processing Record 8 of Set 9 | tiksi
# Processing Record 9 of Set 9 | najran
# Processing Record 10 of Set 9 | kaka
# Processing Record 11 of Set 9 | port elizabeth
# Processing Record 12 of Set 9 | pestovo
# Processing Record 13 of Set 9 | saint-augustin
# Processing Record 14 of Set 9 | norwich
# Processing Record 15 of Set 9 | fare
# Processing Record 16 of Set 9 | bilma
# Processing Record 17 of Set 9 | san quintin
# Processing Record 18 of Set 9 | wageningen
# Processing Record 19 of Set 9 | sukumo
# Processing Record 20 of Set 9 | chincha alta
# Processing Record 21 of Set 9 | nueva imperial
# Processing Record 22 of Set 9 | itacare
# Processing Record 23 of Set 9 | peru
# Processing Record 24 of Set 9 | inuvik
# Processing Record 25 of Set 9 | ambunti
# Processing Record 26 of Set 9 | gao
# Processing Record 27 of Set 9 | san buenaventura
# Processing Record 28 of Set 9 | uulu
# Processing Record 29 of Set 9 | beidao
# Processing Record 30 of Set 9 | jinchengjiang
# City not found. Skipping...
# Processing Record 31 of Set 9 | san juan
# Processing Record 32 of Set 9 | vardo
# Processing Record 33 of Set 9 | tapikan
# Processing Record 34 of Set 9 | morant bay
# Processing Record 35 of Set 9 | kautokeino
# Processing Record 36 of Set 9 | juifang
# City not found. Skipping...
# Processing Record 37 of Set 9 | tual
# Processing Record 38 of Set 9 | aykhal
# Processing Record 39 of Set 9 | blagoveshchenka
# Processing Record 40 of Set 9 | illapel
# Processing Record 41 of Set 9 | jieshi
# Processing Record 42 of Set 9 | zhanaozen
# Processing Record 43 of Set 9 | edson
# Processing Record 44 of Set 9 | melfort
# Processing Record 45 of Set 9 | krasnoyarka
# Processing Record 46 of Set 9 | nuuk
# Processing Record 47 of Set 9 | eldikan
# City not found. Skipping...
# Processing Record 48 of Set 9 | lixourion
# Processing Record 49 of Set 9 | yenagoa
# Processing Record 50 of Set 9 | rio grande
# Processing Record 1 of Set 10 | severnyy-kospashskiy
# Processing Record 2 of Set 10 | biak
# Processing Record 3 of Set 10 | tera
# Processing Record 4 of Set 10 | ilulissat
# Processing Record 5 of Set 10 | sao lourenco do sul
# Processing Record 6 of Set 10 | bahadurgarh
# Processing Record 7 of Set 10 | gulu
# Processing Record 8 of Set 10 | malangali
# Processing Record 9 of Set 10 | new bern
# Processing Record 10 of Set 10 | gainesville
# Processing Record 11 of Set 10 | mabamba
# Processing Record 12 of Set 10 | dalby
# Processing Record 13 of Set 10 | parrita
# Processing Record 14 of Set 10 | victor harbor
# Processing Record 15 of Set 10 | marsa matruh
# Processing Record 16 of Set 10 | mendi
# Processing Record 17 of Set 10 | saint-pierre
# Processing Record 18 of Set 10 | dutlwe
# Processing Record 19 of Set 10 | taltal
# Processing Record 20 of Set 10 | monrovia
# Processing Record 21 of Set 10 | cukai
# Processing Record 22 of Set 10 | areia branca
# Processing Record 23 of Set 10 | el wasta
# City not found. Skipping...
# Processing Record 24 of Set 10 | ust-maya
# Processing Record 25 of Set 10 | maldonado
# Processing Record 26 of Set 10 | otavi
# Processing Record 27 of Set 10 | khor
# Processing Record 28 of Set 10 | honiara
# Processing Record 29 of Set 10 | bintulu
# Processing Record 30 of Set 10 | tromso
# Processing Record 31 of Set 10 | aklavik
# Processing Record 32 of Set 10 | chushan
# Processing Record 33 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 10 | verkhoyansk
# Processing Record 35 of Set 10 | asau
# Processing Record 36 of Set 10 | berbera
# Processing Record 37 of Set 10 | tautira
# Processing Record 38 of Set 10 | hofn
# Processing Record 39 of Set 10 | davila
# Processing Record 40 of Set 10 | watsa
# Processing Record 41 of Set 10 | erenhot
# Processing Record 42 of Set 10 | merrill
# Processing Record 43 of Set 10 | altar
# Processing Record 44 of Set 10 | markova
# Processing Record 45 of Set 10 | terrace
# Processing Record 46 of Set 10 | mananjary
# Processing Record 47 of Set 10 | chaozhou
# Processing Record 48 of Set 10 | ilebo
# Processing Record 49 of Set 10 | dakar
# Processing Record 50 of Set 10 | kimry
# Processing Record 1 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 11 | tepeojuma
# Processing Record 3 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 4 of Set 11 | marawi
# Processing Record 5 of Set 11 | asyut
# Processing Record 6 of Set 11 | san ramon
# Processing Record 7 of Set 11 | faya
# Processing Record 8 of Set 11 | luanda
# Processing Record 9 of Set 11 | scarborough
# Processing Record 10 of Set 11 | marica
# Processing Record 11 of Set 11 | goulburn
# Processing Record 12 of Set 11 | lucea
# Processing Record 13 of Set 11 | nicoya
# Processing Record 14 of Set 11 | sierra vista
# Processing Record 15 of Set 11 | houma
# Processing Record 16 of Set 11 | papillion
# Processing Record 17 of Set 11 | vaitape
# Processing Record 18 of Set 11 | tianmen
# Processing Record 19 of Set 11 | horqueta
# Processing Record 20 of Set 11 | nuziders
# Processing Record 21 of Set 11 | mount gambier
# Processing Record 22 of Set 11 | puerto carreno
# Processing Record 23 of Set 11 | iracoubo
# Processing Record 24 of Set 11 | egvekinot
# Processing Record 25 of Set 11 | oistins
# Processing Record 26 of Set 11 | liwale
# Processing Record 27 of Set 11 | cayenne
# Processing Record 28 of Set 11 | beringovskiy
# Processing Record 29 of Set 11 | husavik
# Processing Record 30 of Set 11 | camopi
# Processing Record 31 of Set 11 | la libertad
# Processing Record 32 of Set 11 | kozhva
# Processing Record 33 of Set 11 | vengurla
# Processing Record 34 of Set 11 | levski
# Processing Record 35 of Set 11 | camana
# Processing Record 36 of Set 11 | dinguiraye
# Processing Record 37 of Set 11 | maceio
# Processing Record 38 of Set 11 | rawson
# Processing Record 39 of Set 11 | varghis
# Processing Record 40 of Set 11 | novoye leushino
# Processing Record 41 of Set 11 | wajima
# Processing Record 42 of Set 11 | beli manastir
# Processing Record 43 of Set 11 | chegdomyn
# Processing Record 44 of Set 11 | havre-saint-pierre
# Processing Record 45 of Set 11 | teabo
# Processing Record 46 of Set 11 | cocobeach
# Processing Record 47 of Set 11 | baykit
# Processing Record 48 of Set 11 | yeniseysk
# Processing Record 49 of Set 11 | kudahuvadhoo
# Processing Record 50 of Set 11 | zyryanovsk
# Processing Record 1 of Set 12 | rognan
# Processing Record 2 of Set 12 | ust-kulom
# Processing Record 3 of Set 12 | catuday
# Processing Record 4 of Set 12 | vagur
# Processing Record 5 of Set 12 | primorsk
# Processing Record 6 of Set 12 | khorramshahr
# Processing Record 7 of Set 12 | doctor arroyo
# Processing Record 8 of Set 12 | biltine
# Processing Record 9 of Set 12 | paredon
# Processing Record 10 of Set 12 | auki
# Processing Record 11 of Set 12 | douentza
# Processing Record 12 of Set 12 | alness
# Processing Record 13 of Set 12 | keffi
# Processing Record 14 of Set 12 | nishihara
# Processing Record 15 of Set 12 | mackenzie
# Processing Record 16 of Set 12 | nanortalik
# Processing Record 17 of Set 12 | seoul
# Processing Record 18 of Set 12 | vanimo
# Processing Record 19 of Set 12 | pouebo
# Processing Record 20 of Set 12 | haverfordwest
# Processing Record 21 of Set 12 | san vicente
# Processing Record 22 of Set 12 | pangnirtung
# Processing Record 23 of Set 12 | dicabisagan
# Processing Record 24 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 12 | sapulpa
# Processing Record 26 of Set 12 | maragogi
# Processing Record 27 of Set 12 | westport
# Processing Record 28 of Set 12 | kungurtug
# Processing Record 29 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 31 of Set 12 | goksun
# Processing Record 32 of Set 12 | sovetskaya gavan
# Processing Record 33 of Set 12 | yeppoon
# Processing Record 34 of Set 12 | maneadero
# Processing Record 35 of Set 12 | lahij
# Processing Record 36 of Set 12 | killybegs
# Processing Record 37 of Set 12 | muravlenko
# Processing Record 38 of Set 12 | beloha
# Processing Record 39 of Set 12 | sur
# Processing Record 40 of Set 12 | solenzo
# Processing Record 41 of Set 12 | mandalgovi
# Processing Record 42 of Set 12 | talnakh
# Processing Record 43 of Set 12 | bellmead
# Processing Record 44 of Set 12 | ballangen
# Processing Record 45 of Set 12 | elko
# Processing Record 46 of Set 12 | jega
# Processing Record 47 of Set 12 | nha trang
# Processing Record 48 of Set 12 | hami
# Processing Record 49 of Set 12 | ajdabiya
# Processing Record 50 of Set 12 | pakokku
# Processing Record 1 of Set 13 | sabang
# Processing Record 2 of Set 13 | samarai
# Processing Record 3 of Set 13 | nalobikha
# Processing Record 4 of Set 13 | katangli
# Processing Record 5 of Set 13 | palmer
# Processing Record 6 of Set 13 | roma
# Processing Record 7 of Set 13 | ribeira do pombal
# Processing Record 8 of Set 13 | nola
# Processing Record 9 of Set 13 | quesnel
# Processing Record 10 of Set 13 | quatre cocos
# Processing Record 11 of Set 13 | tevaitoa
# Processing Record 12 of Set 13 | los llanos de aridane
# Processing Record 13 of Set 13 | labrea
# Processing Record 14 of Set 13 | korcula
# Processing Record 15 of Set 13 | kuching
# Processing Record 16 of Set 13 | paranaiba
# Processing Record 17 of Set 13 | birakan
# Processing Record 18 of Set 13 | gabu
# Processing Record 19 of Set 13 | solnechnyy
# Processing Record 20 of Set 13 | mogadishu
# Processing Record 21 of Set 13 | novyy buh
# Processing Record 22 of Set 13 | vitim
# Processing Record 23 of Set 13 | novaya igirma
# Processing Record 24 of Set 13 | abu samrah
# Processing Record 25 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 26 of Set 13 | puerto escondido
# Processing Record 27 of Set 13 | jalu
# Processing Record 28 of Set 13 | bardiyah
# Processing Record 29 of Set 13 | saint-denis
# Processing Record 30 of Set 13 | deputatskiy
# Processing Record 31 of Set 13 | santa vitoria do palmar
# Processing Record 32 of Set 13 | derzhavinsk
# Processing Record 33 of Set 13 | colares
# Processing Record 34 of Set 13 | podor
# Processing Record 35 of Set 13 | puerto leguizamo
# Processing Record 36 of Set 13 | belmonte
# Processing Record 37 of Set 13 | australind
# Processing Record 38 of Set 13 | cordoba
# Processing Record 39 of Set 13 | kirensk
# Processing Record 40 of Set 13 | dalaba
# Processing Record 41 of Set 13 | high level
# Processing Record 42 of Set 13 | itubera
# Processing Record 43 of Set 13 | dubrovytsya
# Processing Record 44 of Set 13 | kyabe
# Processing Record 45 of Set 13 | asgabat
# Processing Record 46 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 13 | saurimo
# Processing Record 48 of Set 13 | aksu
# Processing Record 49 of Set 13 | rosetta
# Processing Record 50 of Set 13 | lata
# Processing Record 1 of Set 14 | mlonggo
# Processing Record 2 of Set 14 | palmerston north
# Processing Record 3 of Set 14 | banihal
# Processing Record 4 of Set 14 | celestun
# Processing Record 5 of Set 14 | abaetetuba
# Processing Record 6 of Set 14 | tunxi
# City not found. Skipping...
# Processing Record 7 of Set 14 | andra
# Processing Record 8 of Set 14 | albury
# Processing Record 9 of Set 14 | tsabong
# Processing Record 10 of Set 14 | sakakah
# Processing Record 11 of Set 14 | pyu
# Processing Record 12 of Set 14 | kofele
# Processing Record 13 of Set 14 | tuatapere
# Processing Record 14 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 15 of Set 14 | la roda
# Processing Record 16 of Set 14 | narsaq
# Processing Record 17 of Set 14 | severomuysk
# Processing Record 18 of Set 14 | matamoros
# Processing Record 19 of Set 14 | porto murtinho
# Processing Record 20 of Set 14 | benghazi
# Processing Record 21 of Set 14 | isangel
# Processing Record 22 of Set 14 | kizukuri
# Processing Record 23 of Set 14 | sideropolis
# Processing Record 24 of Set 14 | kirakira
# Processing Record 25 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 14 | sioux lookout
# Processing Record 27 of Set 14 | sistranda
# Processing Record 28 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 29 of Set 14 | kampene
# Processing Record 30 of Set 14 | chaiya
# Processing Record 31 of Set 14 | borogontsy
# Processing Record 32 of Set 14 | novodugino
# Processing Record 33 of Set 14 | koboldo
# City not found. Skipping...
# Processing Record 34 of Set 14 | tiarei
# Processing Record 35 of Set 14 | gap
# Processing Record 36 of Set 14 | aasiaat
# Processing Record 37 of Set 14 | yamada
# Processing Record 38 of Set 14 | qasigiannguit
# Processing Record 39 of Set 14 | manavgat
# Processing Record 40 of Set 14 | salinopolis
# Processing Record 41 of Set 14 | hope
# Processing Record 42 of Set 14 | inongo
# Processing Record 43 of Set 14 | kot diji
# Processing Record 44 of Set 14 | nowy targ
# Processing Record 45 of Set 14 | lakatoro
# Processing Record 46 of Set 14 | ancona
# Processing Record 47 of Set 14 | hamada
# Processing Record 48 of Set 14 | asfi
# Processing Record 49 of Set 14 | parainen
# Processing Record 50 of Set 14 | toulepleu
# City not found. Skipping...
# Processing Record 1 of Set 15 | donji milanovac
# Processing Record 2 of Set 15 | loganville
# Processing Record 3 of Set 15 | bismarck
# Processing Record 4 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 5 of Set 15 | kabare
# Processing Record 6 of Set 15 | antofagasta
# Processing Record 7 of Set 15 | port hardy
# Processing Record 8 of Set 15 | sudak
# Processing Record 9 of Set 15 | south lake tahoe
# Processing Record 10 of Set 15 | la aldea
# Processing Record 11 of Set 15 | kamaishi
# Processing Record 12 of Set 15 | alofi
# Processing Record 13 of Set 15 | touros
# Processing Record 14 of Set 15 | nesna
# Processing Record 15 of Set 15 | shingu
# Processing Record 16 of Set 15 | nargana
# Processing Record 17 of Set 15 | necochea
# Processing Record 18 of Set 15 | hirara
# Processing Record 19 of Set 15 | padang
# Processing Record 20 of Set 15 | wau
# Processing Record 21 of Set 15 | changji
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
city_data
# Out:
# [{'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 64.26,
#   'Current Description': 'clear sky',
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'AR'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 43.2,
#   'Current Description': 'overcast clouds',
#   'Humidity': 56,
#   'Cloudiness': 94,
#   'Wind Speed': 6.67,
#   'Country': 'RU'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 54.09,
#   'Current Description': 'clear sky',
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'AR'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 69.76,
#   'Current Description': 'broken clouds',
#   'Humidity': 49,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'BR'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 49.08,
#   'Current Description': 'overcast clouds',
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 27.18,
#   'Country': 'AU'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 55.11,
#   'Current Description': 'few clouds',
#   'Humidity': 90,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'ZA'},
#  {'City': 'Broome',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp': 73.98,
#   'Current Description': 'overcast clouds',
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Country': 'US'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 51.91,
#   'Current Description': 'broken clouds',
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 13.42,
#   'Country': 'RU'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 79.29,
#   'Current Description': 'scattered clouds',
#   'Humidity': 86,
#   'Cloudiness': 50,
#   'Wind Speed': 7.16,
#   'Country': 'JP'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 71.85,
#   'Current Description': 'scattered clouds',
#   'Humidity': 77,
#   'Cloudiness': 35,
#   'Wind Speed': 7.94,
#   'Country': 'PF'},
#  {'City': 'Marquette',
#   'Lat': 46.5333,
#   'Lng': -87.6335,
#   'Max Temp': 65.82,
#   'Current Description': 'broken clouds',
#   'Humidity': 71,
#   'Cloudiness': 56,
#   'Wind Speed': 12.44,
#   'Country': 'US'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 66.67,
#   'Current Description': 'clear sky',
#   'Humidity': 61,
#   'Cloudiness': 1,
#   'Wind Speed': 19.57,
#   'Country': 'CA'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 67.59,
#   'Current Description': 'light rain',
#   'Humidity': 84,
#   'Cloudiness': 90,
#   'Wind Speed': 17.22,
#   'Country': 'RE'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 53.76,
#   'Current Description': 'broken clouds',
#   'Humidity': 69,
#   'Cloudiness': 68,
#   'Wind Speed': 2.57,
#   'Country': 'GL'},
#  {'City': 'Krasnyy Yar',
#   'Lat': 46.5331,
#   'Lng': 48.3456,
#   'Max Temp': 70.97,
#   'Current Description': 'clear sky',
#   'Humidity': 62,
#   'Cloudiness': 2,
#   'Wind Speed': 7.78,
#   'Country': 'RU'},
#  {'City': 'Waingapu',
#   'Lat': -9.6567,
#   'Lng': 120.2641,
#   'Max Temp': 73.92,
#   'Current Description': 'overcast clouds',
#   'Humidity': 82,
#   'Cloudiness': 91,
#   'Wind Speed': 8.77,
#   'Country': 'ID'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 73.94,
#   'Current Description': 'clear sky',
#   'Humidity': 48,
#   'Cloudiness': 10,
#   'Wind Speed': 3.56,
#   'Country': 'RU'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 82.35,
#   'Current Description': 'overcast clouds',
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 5.23,
#   'Country': 'MV'},
#  {'City': 'Charters Towers',
#   'Lat': -20.1,
#   'Lng': 146.2667,
#   'Max Temp': 66.79,
#   'Current Description': 'scattered clouds',
#   'Humidity': 44,
#   'Cloudiness': 36,
#   'Wind Speed': 6.11,
#   'Country': 'AU'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 79.02,
#   'Current Description': 'scattered clouds',
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 8.99,
#   'Country': 'US'},
#  {'City': 'Maumere',
#   'Lat': -8.6199,
#   'Lng': 122.2111,
#   'Max Temp': 77.31,
#   'Current Description': 'broken clouds',
#   'Humidity': 84,
#   'Cloudiness': 62,
#   'Wind Speed': 7.27,
#   'Country': 'ID'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 39.31,
#   'Current Description': 'clear sky',
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41,
#   'Country': 'CL'},
#  {'City': 'Vuktyl',
#   'Lat': 63.8567,
#   'Lng': 57.3094,
#   'Max Temp': 44.22,
#   'Current Description': 'overcast clouds',
#   'Humidity': 89,
#   'Cloudiness': 92,
#   'Wind Speed': 0.67,
#   'Country': 'RU'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 59.4,
#   'Current Description': 'overcast clouds',
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 13.18,
#   'Country': 'NZ'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 82.13,
#   'Current Description': 'broken clouds',
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'US'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 51.12,
#   'Current Description': 'clear sky',
#   'Humidity': 82,
#   'Cloudiness': 3,
#   'Wind Speed': 6.91,
#   'Country': 'ZA'},
#  {'City': 'Abeche',
#   'Lat': 13.8292,
#   'Lng': 20.8324,
#   'Max Temp': 76.01,
#   'Current Description': 'overcast clouds',
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 4.12,
#   'Country': 'TD'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 74.39,
#   'Current Description': 'scattered clouds',
#   'Humidity': 91,
#   'Cloudiness': 32,
#   'Wind Speed': 4.72,
#   'Country': 'ID'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 65.39,
#   'Current Description': 'few clouds',
#   'Humidity': 89,
#   'Cloudiness': 14,
#   'Wind Speed': 4.21,
#   'Country': 'RU'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 70.41,
#   'Current Description': 'clear sky',
#   'Humidity': 88,
#   'Cloudiness': 6,
#   'Wind Speed': 10.2,
#   'Country': 'PT'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 44.26,
#   'Current Description': 'few clouds',
#   'Humidity': 42,
#   'Cloudiness': 20,
#   'Wind Speed': 19.57,
#   'Country': 'AR'},
#  {'City': 'Saint-Joseph',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 66.58,
#   'Current Description': 'light rain',
#   'Humidity': 82,
#   'Cloudiness': 61,
#   'Wind Speed': 16.89,
#   'Country': 'RE'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 43.81,
#   'Current Description': 'light rain',
#   'Humidity': 76,
#   'Cloudiness': 93,
#   'Wind Speed': 6.8,
#   'Country': 'NZ'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 70.66,
#   'Current Description': 'overcast clouds',
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 5.61,
#   'Country': 'US'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 56.73,
#   'Current Description': 'clear sky',
#   'Humidity': 84,
#   'Cloudiness': 1,
#   'Wind Speed': 10.25,
#   'Country': 'ZA'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 93.02,
#   'Current Description': 'mist',
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Country': 'US'},
#  {'City': 'Coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 53.33,
#   'Current Description': 'scattered clouds',
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'CL'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 46.76,
#   'Current Description': 'overcast clouds',
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'AU'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 75.16,
#   'Current Description': 'scattered clouds',
#   'Humidity': 79,
#   'Cloudiness': 48,
#   'Wind Speed': 9.75,
#   'Country': 'EC'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 50.88,
#   'Current Description': 'clear sky',
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 6.44,
#   'Country': 'ZA'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 54.9,
#   'Current Description': 'few clouds',
#   'Humidity': 83,
#   'Cloudiness': 12,
#   'Wind Speed': 6.13,
#   'Country': 'ZA'},
#  {'City': 'Rosarito',
#   'Lat': 32.3333,
#   'Lng': -117.0333,
#   'Max Temp': 95.94,
#   'Current Description': 'scattered clouds',
#   'Humidity': 59,
#   'Cloudiness': 29,
#   'Wind Speed': 14.72,
#   'Country': 'MX'},
#  {'City': 'Kolosovka',
#   'Lat': 56.4678,
#   'Lng': 73.611,
#   'Max Temp': 50.9,
#   'Current Description': 'broken clouds',
#   'Humidity': 68,
#   'Cloudiness': 66,
#   'Wind Speed': 6.17,
#   'Country': 'RU'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 64.47,
#   'Current Description': 'broken clouds',
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'AU'},
#  {'City': 'Korla',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 88.97,
#   'Current Description': 'scattered clouds',
#   'Humidity': 22,
#   'Cloudiness': 35,
#   'Wind Speed': 19.71,
#   'Country': 'CN'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 82.29,
#   'Current Description': 'few clouds',
#   'Humidity': 77,
#   'Cloudiness': 11,
#   'Wind Speed': 2.95,
#   'Country': 'PG'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 47.21,
#   'Current Description': 'clear sky',
#   'Humidity': 65,
#   'Cloudiness': 6,
#   'Wind Speed': 9.82,
#   'Country': 'BR'},
#  {'City': 'Karaton',
#   'Lat': -6.3424,
#   'Lng': 106.1045,
#   'Max Temp': 78.96,
#   'Current Description': 'clear sky',
#   'Humidity': 89,
#   'Cloudiness': 5,
#   'Wind Speed': 1.05,
#   'Country': 'ID'},
#  {'City': 'Fernley',
#   'Lat': 39.608,
#   'Lng': -119.2518,
#   'Max Temp': 99.32,
#   'Current Description': 'scattered clouds',
#   'Humidity': 14,
#   'Cloudiness': 30,
#   'Wind Speed': 7.65,
#   'Country': 'US'},
#  {'City': 'Sembabule',
#   'Lat': -0.0772,
#   'Lng': 31.4567,
#   'Max Temp': 64.27,
#   'Current Description': 'broken clouds',
#   'Humidity': 71,
#   'Cloudiness': 57,
#   'Wind Speed': 1.68,
#   'Country': 'UG'},
#  {'City': 'Qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 55.9,
#   'Current Description': 'broken clouds',
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 3.49,
#   'Country': 'GL'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 53.62,
#   'Current Description': 'overcast clouds',
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'US'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 36.12,
#   'Current Description': 'overcast clouds',
#   'Humidity': 69,
#   'Cloudiness': 99,
#   'Wind Speed': 20.2,
#   'Country': 'RU'},
#  {'City': 'Porto Santo',
#   'Lat': 33.072,
#   'Lng': -16.3415,
#   'Max Temp': 71.51,
#   'Current Description': 'few clouds',
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 17.27,
#   'Country': 'PT'},
#  {'City': 'Ihtiman',
#   'Lat': 42.4333,
#   'Lng': 23.8167,
#   'Max Temp': 76.71,
#   'Current Description': 'clear sky',
#   'Humidity': 72,
#   'Cloudiness': 4,
#   'Wind Speed': 2.39,
#   'Country': 'BG'},
#  {'City': 'Zhigansk',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': 61.36,
#   'Current Description': 'clear sky',
#   'Humidity': 47,
#   'Cloudiness': 7,
#   'Wind Speed': 6.17,
#   'Country': 'RU'},
#  {'City': 'Labuhan',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 75.09,
#   'Current Description': 'overcast clouds',
#   'Humidity': 88,
#   'Cloudiness': 95,
#   'Wind Speed': 6.58,
#   'Country': 'ID'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 104.63,
#   'Current Description': 'clear sky',
#   'Humidity': 22,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 50.54,
#   'Current Description': 'clear sky',
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 6.17,
#   'Country': 'CL'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 44.65,
#   'Current Description': 'clear sky',
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 6.53,
#   'Country': 'ZA'},
#  {'City': 'Ekibastuz',
#   'Lat': 51.6667,
#   'Lng': 75.3667,
#   'Max Temp': 58.68,
#   'Current Description': 'few clouds',
#   'Humidity': 49,
#   'Cloudiness': 20,
#   'Wind Speed': 6.49,
#   'Country': 'KZ'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 80.78,
#   'Current Description': 'broken clouds',
#   'Humidity': 73,
#   'Cloudiness': 56,
#   'Wind Speed': 6.53,
#   'Country': 'VE'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 56.71,
#   'Current Description': 'overcast clouds',
#   'Humidity': 67,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 41.74,
#   'Current Description': 'scattered clouds',
#   'Humidity': 89,
#   'Cloudiness': 41,
#   'Wind Speed': 5.55,
#   'Country': 'RU'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 60.8,
#   'Current Description': 'overcast clouds',
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'CA'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 39.43,
#   'Current Description': 'overcast clouds',
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 7.4,
#   'Country': 'GL'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 70.32,
#   'Current Description': 'scattered clouds',
#   'Humidity': 49,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'CA'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 83.25,
#   'Current Description': 'few clouds',
#   'Humidity': 73,
#   'Cloudiness': 16,
#   'Wind Speed': 11.12,
#   'Country': 'KI'},
#  {'City': 'Stepnyak',
#   'Lat': 52.8339,
#   'Lng': 70.7803,
#   'Max Temp': 52.39,
#   'Current Description': 'clear sky',
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 6.24,
#   'Country': 'KZ'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 31.98,
#   'Current Description': 'snow',
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 25.08,
#   'Country': 'RU'},
#  {'City': 'Whitecourt',
#   'Lat': 54.1502,
#   'Lng': -115.6855,
#   'Max Temp': 81.64,
#   'Current Description': 'few clouds',
#   'Humidity': 39,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'CA'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 77,
#   'Current Description': 'overcast clouds',
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 31.7,
#   'Country': 'SO'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 36.43,
#   'Current Description': 'clear sky',
#   'Humidity': 60,
#   'Cloudiness': 4,
#   'Wind Speed': 2.01,
#   'Country': 'BR'},
#  {'City': 'Qui Nhon',
#   'Lat': 13.7667,
#   'Lng': 109.2333,
#   'Max Temp': 83.64,
#   'Current Description': 'broken clouds',
#   'Humidity': 71,
#   'Cloudiness': 60,
#   'Wind Speed': 14.67,
#   'Country': 'VN'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 45.05,
#   'Current Description': 'broken clouds',
#   'Humidity': 80,
#   'Cloudiness': 84,
#   'Wind Speed': 6.15,
#   'Country': 'NZ'},
#  {'City': 'Fairbanks',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': 67.23,
#   'Current Description': 'overcast clouds',
#   'Humidity': 63,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'US'},
#  {'City': 'Goderich',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 73.9,
#   'Current Description': 'clear sky',
#   'Humidity': 78,
#   'Cloudiness': 7,
#   'Wind Speed': 11.5,
#   'Country': 'CA'},
#  {'City': 'Sao Pedro',
#   'Lat': -22.5486,
#   'Lng': -47.9139,
#   'Max Temp': 49.57,
#   'Current Description': 'scattered clouds',
#   'Humidity': 30,
#   'Cloudiness': 37,
#   'Wind Speed': 3.33,
#   'Country': 'BR'},
#  {'City': 'Tabou',
#   'Lat': 4.423,
#   'Lng': -7.3528,
#   'Max Temp': 76.15,
#   'Current Description': 'light rain',
#   'Humidity': 85,
#   'Cloudiness': 82,
#   'Wind Speed': 5.93,
#   'Country': 'CI'},
#  {'City': 'Bubaque',
#   'Lat': 11.2833,
#   'Lng': -15.8333,
#   'Max Temp': 77.58,
#   'Current Description': 'overcast clouds',
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 10.94,
#   'Country': 'GW'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 83.01,
#   'Current Description': 'few clouds',
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Country': 'BB'},
#  {'City': 'Port Hedland',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 64.45,
#   'Current Description': 'scattered clouds',
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'AU'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.27,
#   'Current Description': 'few clouds',
#   'Humidity': 78,
#   'Cloudiness': 17,
#   'Wind Speed': 13.96,
#   'Country': 'PF'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 73.04,
#   'Current Description': 'overcast clouds',
#   'Humidity': 91,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Country': 'US'},
#  {'City': 'Kahramanmaras',
#   'Lat': 38,
#   'Lng': 37,
#   'Max Temp': 68.63,
#   'Current Description': 'clear sky',
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 6.26,
#   'Country': 'TR'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 67.89,
#   'Current Description': 'clear sky',
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US'},
#  {'City': 'Zeya',
#   'Lat': 53.75,
#   'Lng': 127.2667,
#   'Max Temp': 60.96,
#   'Current Description': 'scattered clouds',
#   'Humidity': 95,
#   'Cloudiness': 50,
#   'Wind Speed': 6.11,
#   'Country': 'RU'},
#  {'City': 'Arlit',
#   'Lat': 18.7369,
#   'Lng': 7.3853,
#   'Max Temp': 98.44,
#   'Current Description': 'broken clouds',
#   'Humidity': 26,
#   'Cloudiness': 68,
#   'Wind Speed': 7.65,
#   'Country': 'NE'},
#  {'City': 'Batagay',
#   'Lat': 67.6333,
#   'Lng': 134.6333,
#   'Max Temp': 57.47,
#   'Current Description': 'scattered clouds',
#   'Humidity': 48,
#   'Cloudiness': 45,
#   'Wind Speed': 2.01,
#   'Country': 'RU'},
#  {'City': 'Klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 52.72,
#   'Current Description': 'overcast clouds',
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 14.41,
#   'Country': 'FO'},
#  {'City': 'Pittsburg',
#   'Lat': 38.028,
#   'Lng': -121.8847,
#   'Max Temp': 105.06,
#   'Current Description': 'clear sky',
#   'Humidity': 30,
#   'Cloudiness': 1,
#   'Wind Speed': 5.01,
#   'Country': 'US'},
#  {'City': 'Takoradi',
#   'Lat': 4.8845,
#   'Lng': -1.7554,
#   'Max Temp': 76.05,
#   'Current Description': 'scattered clouds',
#   'Humidity': 86,
#   'Cloudiness': 46,
#   'Wind Speed': 7.99,
#   'Country': 'GH'},
#  {'City': 'Lakes Entrance',
#   'Lat': -37.8811,
#   'Lng': 147.981,
#   'Max Temp': 46.18,
#   'Current Description': 'clear sky',
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 9.82,
#   'Country': 'AU'},
#  {'City': 'Puruliya',
#   'Lat': 23.3333,
#   'Lng': 86.3667,
#   'Max Temp': 76.62,
#   'Current Description': 'moderate rain',
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.9,
#   'Country': 'IN'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 69.19,
#   'Current Description': 'clear sky',
#   'Humidity': 64,
#   'Cloudiness': 1,
#   'Wind Speed': 11.18,
#   'Country': 'RU'},
#  {'City': 'Nacozari',
#   'Lat': 25.3366,
#   'Lng': -108.2574,
#   'Max Temp': 101.1,
#   'Current Description': 'scattered clouds',
#   'Humidity': 60,
#   'Cloudiness': 28,
#   'Wind Speed': 13.58,
#   'Country': 'MX'},
#  {'City': 'Cockburn Town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 82.2,
#   'Current Description': 'clear sky',
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 19.6,
#   'Country': 'TC'},
#  {'City': 'Guilin',
#   'Lat': 25.2819,
#   'Lng': 110.2864,
#   'Max Temp': 78.91,
#   'Current Description': 'broken clouds',
#   'Humidity': 94,
#   'Cloudiness': 74,
#   'Wind Speed': 0.47,
#   'Country': 'CN'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 43.48,
#   'Current Description': 'heavy intensity rain',
#   'Humidity': 84,
#   'Cloudiness': 97,
#   'Wind Speed': 3.71,
#   'Country': 'NZ'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 84.11,
#   'Current Description': 'scattered clouds',
#   'Humidity': 85,
#   'Cloudiness': 47,
#   'Wind Speed': 6.11,
#   'Country': 'JP'},
#  {'City': 'Tubuala',
#   'Lat': 9.5167,
#   'Lng': -79.0333,
#   'Max Temp': 78.33,
#   'Current Description': 'overcast clouds',
#   'Humidity': 79,
#   'Cloudiness': 93,
#   'Wind Speed': 8.19,
#   'Country': 'PA'},
#  {'City': 'Itarema',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 78.78,
#   'Current Description': 'broken clouds',
#   'Humidity': 82,
#   'Cloudiness': 82,
#   'Wind Speed': 12.5,
#   'Country': 'BR'},
#  {'City': 'Hovd',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': 60.35,
#   'Current Description': 'clear sky',
#   'Humidity': 49,
#   'Cloudiness': 5,
#   'Wind Speed': 0.22,
#   'Country': 'MN'},
#  {'City': 'Whitianga',
#   'Lat': -36.8333,
#   'Lng': 175.7,
#   'Max Temp': 59.02,
#   'Current Description': 'few clouds',
#   'Humidity': 80,
#   'Cloudiness': 19,
#   'Wind Speed': 4.09,
#   'Country': 'NZ'},
#  {'City': 'Abu Kamal',
#   'Lat': 34.4506,
#   'Lng': 40.9171,
#   'Max Temp': 92.21,
#   'Current Description': 'clear sky',
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 16.71,
#   'Country': 'SY'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 68.29,
#   'Current Description': 'light rain',
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 21.85,
#   'Country': 'MU'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 48.52,
#   'Current Description': 'scattered clouds',
#   'Humidity': 55,
#   'Cloudiness': 44,
#   'Wind Speed': 23.06,
#   'Country': 'AU'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 44.58,
#   'Current Description': 'broken clouds',
#   'Humidity': 76,
#   'Cloudiness': 82,
#   'Wind Speed': 5.88,
#   'Country': 'UY'},
#  {'City': 'Cap Malheureux',
#   'Lat': -19.9842,
#   'Lng': 57.6142,
#   'Max Temp': 68.49,
#   'Current Description': 'light rain',
#   'Humidity': 78,
#   'Cloudiness': 41,
#   'Wind Speed': 11.99,
#   'Country': 'MU'},
#  {'City': 'Mazamari',
#   'Lat': -11.3258,
#   'Lng': -74.5308,
#   'Max Temp': 64.63,
#   'Current Description': 'overcast clouds',
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 1.61,
#   'Country': 'PE'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 47.12,
#   'Current Description': 'light rain',
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 4,
#   'Country': 'AU'},
#  {'City': 'Boali',
#   'Lat': 4.8005,
#   'Lng': 18.1275,
#   'Max Temp': 78.67,
#   'Current Description': 'overcast clouds',
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 2.08,
#   'Country': 'CF'},
#  {'City': 'Port Pirie',
#   'Lat': -33.1833,
#   'Lng': 138.0167,
#   'Max Temp': 60.89,
#   'Current Description': 'broken clouds',
#   'Humidity': 48,
#   'Cloudiness': 68,
#   'Wind Speed': 14.18,
#   'Country': 'AU'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 77.05,
#   'Current Description': 'broken clouds',
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CK'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 75.36,
#   'Current Description': 'few clouds',
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'TO'},
#  {'City': 'Muyezerskiy',
#   'Lat': 63.9333,
#   'Lng': 31.65,
#   'Max Temp': 57.38,
#   'Current Description': 'overcast clouds',
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 6.73,
#   'Country': 'RU'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 83.14,
#   'Current Description': 'light rain',
#   'Humidity': 74,
#   'Cloudiness': 32,
#   'Wind Speed': 6.82,
#   'Country': 'PG'},
#  {'City': 'Mugur-Aksy',
#   'Lat': 50.35,
#   'Lng': 90.5,
#   'Max Temp': 48.49,
#   'Current Description': 'overcast clouds',
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'RU'},
#  {'City': 'Kapoeta',
#   'Lat': 4.7717,
#   'Lng': 33.5903,
#   'Max Temp': 74.5,
#   'Current Description': 'broken clouds',
#   'Humidity': 59,
#   'Cloudiness': 77,
#   'Wind Speed': 5.39,
#   'Country': 'SS'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 59.11,
#   'Current Description': 'clear sky',
#   'Humidity': 71,
#   'Cloudiness': 2,
#   'Wind Speed': 9.1,
#   'Country': 'ZA'},
#  {'City': 'Baruun-Urt',
#   'Lat': 46.6806,
#   'Lng': 113.2792,
#   'Max Temp': 63.12,
#   'Current Description': 'few clouds',
#   'Humidity': 81,
#   'Cloudiness': 19,
#   'Wind Speed': 6.53,
#   'Country': 'MN'},
#  {'City': 'Chernyshevskiy',
#   'Lat': 63.0128,
#   'Lng': 112.4714,
#   'Max Temp': 56.93,
#   'Current Description': 'few clouds',
#   'Humidity': 56,
#   'Cloudiness': 11,
#   'Wind Speed': 2.93,
#   'Country': 'RU'},
#  {'City': 'Mafinga',
#   'Lat': -7.25,
#   'Lng': 35.0667,
#   'Max Temp': 63.72,
#   'Current Description': 'clear sky',
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 3.11,
#   'Country': 'TZ'},
#  {'City': 'Svetlogorsk',
#   'Lat': 52.6333,
#   'Lng': 29.7333,
#   'Max Temp': 64.08,
#   'Current Description': 'scattered clouds',
#   'Humidity': 97,
#   'Cloudiness': 29,
#   'Wind Speed': 6.42,
#   'Country': 'BY'},
#  {'City': 'Kloulklubed',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 77.5,
#   'Current Description': 'overcast clouds',
#   'Humidity': 72,
#   'Cloudiness': 98,
#   'Wind Speed': 3.6,
#   'Country': 'PW'},
#  {'City': 'Tezu',
#   'Lat': 27.9167,
#   'Lng': 96.1667,
#   'Max Temp': 75.88,
#   'Current Description': 'overcast clouds',
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.32,
#   'Country': 'IN'},
#  {'City': 'Kamenka',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 69.62,
#   'Current Description': 'scattered clouds',
#   'Humidity': 70,
#   'Cloudiness': 33,
#   'Wind Speed': 7.56,
#   'Country': 'RU'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 62.42,
#   'Current Description': 'clear sky',
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 9.42,
#   'Country': 'NA'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 51.53,
#   'Current Description': 'scattered clouds',
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'CA'},
#  {'City': 'Opuwo',
#   'Lat': -18.0607,
#   'Lng': 13.84,
#   'Max Temp': 59.29,
#   'Current Description': 'clear sky',
#   'Humidity': 26,
#   'Cloudiness': 8,
#   'Wind Speed': 8.63,
#   'Country': 'NA'},
#  {'City': 'Altay',
#   'Lat': 47.8667,
#   'Lng': 88.1167,
#   'Max Temp': 64.27,
#   'Current Description': 'broken clouds',
#   'Humidity': 18,
#   'Cloudiness': 58,
#   'Wind Speed': 5.48,
#   'Country': 'CN'},
#  {'City': 'Avera',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 98.71,
#   'Current Description': 'clear sky',
#   'Humidity': 38,
#   'Cloudiness': 3,
#   'Wind Speed': 6.26,
#   'Country': 'US'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 86.32,
#   'Current Description': 'light rain',
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 4,
#   'Country': 'US'},
#  {'City': 'Nome',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 50.16,
#   'Current Description': 'light rain',
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'US'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 93.61,
#   'Current Description': 'few clouds',
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 5.01,
#   'Country': 'MX'},
#  {'City': 'Bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': 38.28,
#   'Current Description': 'overcast clouds',
#   'Humidity': 62,
#   'Cloudiness': 97,
#   'Wind Speed': 4.88,
#   'Country': 'RU'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 68.25,
#   'Current Description': 'light rain',
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 21.85,
#   'Country': 'MU'},
#  {'City': 'Saint-Francois',
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Max Temp': 65.17,
#   'Current Description': 'clear sky',
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'FR'},
#  {'City': 'Okhotsk',
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': 58.87,
#   'Current Description': 'overcast clouds',
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 8.93,
#   'Country': 'RU'},
#  {'City': 'Pokhara',
#   'Lat': 28.2333,
#   'Lng': 83.9833,
#   'Max Temp': 72.75,
#   'Current Description': 'overcast clouds',
#   'Humidity': 86,
#   'Cloudiness': 94,
#   'Wind Speed': 1.01,
#   'Country': 'NP'},
#  {'City': 'Alyangula',
#   'Lat': -13.8483,
#   'Lng': 136.4192,
#   'Max Temp': 66.07,
#   'Current Description': 'clear sky',
#   'Humidity': 100,
#   'Cloudiness': 4,
#   'Wind Speed': 0,
#   'Country': 'AU'},
#  {'City': 'Matane',
#   'Lat': 48.8286,
#   'Lng': -67.522,
#   'Max Temp': 65.95,
#   'Current Description': 'overcast clouds',
#   'Humidity': 77,
#   'Cloudiness': 92,
#   'Wind Speed': 6.64,
#   'Country': 'CA'},
#  {'City': 'Hays',
#   'Lat': 30.0502,
#   'Lng': -98.0336,
#   'Max Temp': 92.95,
#   'Current Description': 'overcast clouds',
#   'Humidity': 68,
#   'Cloudiness': 96,
#   'Wind Speed': 5.01,
#   'Country': 'US'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 72.72,
#   'Current Description': 'few clouds',
#   'Humidity': 75,
#   'Cloudiness': 18,
#   'Wind Speed': 6.87,
#   'Country': 'PT'},
#  {'City': 'Sidi Ali',
#   'Lat': 36.0998,
#   'Lng': 0.4206,
#   'Max Temp': 73.24,
#   'Current Description': 'broken clouds',
#   'Humidity': 85,
#   'Cloudiness': 68,
#   'Wind Speed': 2.13,
#   'Country': 'DZ'},
#  {'City': 'Walvis Bay',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 52.75,
#   'Current Description': 'clear sky',
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'NA'},
#  {'City': 'La Ronge',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': 80.85,
#   'Current Description': 'broken clouds',
#   'Humidity': 34,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CA'},
#  {'City': 'Pasighat',
#   'Lat': 28.0667,
#   'Lng': 95.3333,
#   'Max Temp': 77.11,
#   'Current Description': 'overcast clouds',
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'IN'},
#  {'City': 'Sayyan',
#   'Lat': 15.1718,
#   'Lng': 44.3244,
#   'Max Temp': 63.72,
#   'Current Description': 'broken clouds',
#   'Humidity': 70,
#   'Cloudiness': 73,
#   'Wind Speed': 0.89,
#   'Country': 'YE'},
#  {'City': 'Mitu',
#   'Lat': 1.1983,
#   'Lng': -70.1733,
#   'Max Temp': 73.62,
#   'Current Description': 'overcast clouds',
#   'Humidity': 92,
#   'Cloudiness': 97,
#   'Wind Speed': 4.61,
#   'Country': 'CO'},
#  {'City': 'Szczecinek',
#   'Lat': 53.7079,
#   'Lng': 16.6994,
#   'Max Temp': 63.34,
#   'Current Description': 'few clouds',
#   'Humidity': 65,
#   'Cloudiness': 23,
#   'Wind Speed': 7.7,
#   'Country': 'PL'},
#  {'City': 'Sola',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 81.27,
#   'Current Description': 'overcast clouds',
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'VU'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 75.36,
#   'Current Description': 'scattered clouds',
#   'Humidity': 35,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'CA'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 62.24,
#   'Current Description': 'few clouds',
#   'Humidity': 57,
#   'Cloudiness': 16,
#   'Wind Speed': 25.66,
#   'Country': 'BR'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 84.18,
#   'Current Description': 'light rain',
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 3.71,
#   'Country': 'HK'},
#  {'City': 'Shakawe',
#   'Lat': -18.3667,
#   'Lng': 21.85,
#   'Max Temp': 53.08,
#   'Current Description': 'broken clouds',
#   'Humidity': 38,
#   'Cloudiness': 52,
#   'Wind Speed': 5.66,
#   'Country': 'BW'},
#  {'City': 'Botwood',
#   'Lat': 49.1499,
#   'Lng': -55.3482,
#   'Max Temp': 69.28,
#   'Current Description': 'broken clouds',
#   'Humidity': 57,
#   'Cloudiness': 77,
#   'Wind Speed': 10.47,
#   'Country': 'CA'},
#  {'City': 'Ola',
#   'Lat': 59.5833,
#   'Lng': 151.2833,
#   'Max Temp': 50.76,
#   'Current Description': 'clear sky',
#   'Humidity': 51,
#   'Cloudiness': 2,
#   'Wind Speed': 15.48,
#   'Country': 'RU'},
#  {'City': 'Noumea',
#   'Lat': -22.2763,
#   'Lng': 166.4572,
#   'Max Temp': 73.38,
#   'Current Description': 'broken clouds',
#   'Humidity': 99,
#   'Cloudiness': 71,
#   'Wind Speed': 7.45,
#   'Country': 'NC'},
#  {'City': 'Mala',
#   'Lat': -12.6581,
#   'Lng': -76.6308,
#   'Max Temp': 64.92,
#   'Current Description': 'scattered clouds',
#   'Humidity': 80,
#   'Cloudiness': 40,
#   'Wind Speed': 4.47,
#   'Country': 'PE'},
#  {'City': 'Mount Isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 58.77,
#   'Current Description': 'clear sky',
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'AU'},
#  {'City': 'Ladysmith',
#   'Lat': 48.9829,
#   'Lng': -123.8194,
#   'Max Temp': 87.24,
#   'Current Description': 'few clouds',
#   'Humidity': 37,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'CA'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 51.64,
#   'Current Description': 'overcast clouds',
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 22.28,
#   'Country': 'AU'},
#  {'City': 'Gouyave',
#   'Lat': 12.1646,
#   'Lng': -61.7296,
#   'Max Temp': 81.37,
#   'Current Description': 'few clouds',
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Country': 'GD'},
#  {'City': 'Presidente Medici',
#   'Lat': -11.1753,
#   'Lng': -61.9014,
#   'Max Temp': 74.68,
#   'Current Description': 'clear sky',
#   'Humidity': 28,
#   'Cloudiness': 4,
#   'Wind Speed': 4.68,
#   'Country': 'BR'},
#  {'City': 'Gladstone',
#   'Lat': -23.85,
#   'Lng': 151.25,
#   'Max Temp': 63.79,
#   'Current Description': 'clear sky',
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'AU'},
#  {'City': 'Kulhudhuffushi',
#   'Lat': 6.6221,
#   'Lng': 73.07,
#   'Max Temp': 82.63,
#   'Current Description': 'scattered clouds',
#   'Humidity': 74,
#   'Cloudiness': 26,
#   'Wind Speed': 12.8,
#   'Country': 'MV'},
#  {'City': 'Kolpny',
#   'Lat': 52.2282,
#   'Lng': 37.0368,
#   'Max Temp': 69.73,
#   'Current Description': 'broken clouds',
#   'Humidity': 69,
#   'Cloudiness': 52,
#   'Wind Speed': 6.67,
#   'Country': 'RU'},
#  {'City': 'Praia Da Vitoria',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 74.75,
#   'Current Description': 'broken clouds',
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 9.8,
#   'Country': 'PT'},
#  {'City': 'Nantucket',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 71.71,
#   'Current Description': 'clear sky',
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 17.27,
#   'Country': 'US'},
#  {'City': 'Shelburne',
#   'Lat': 44.0787,
#   'Lng': -80.2041,
#   'Max Temp': 73.76,
#   'Current Description': 'broken clouds',
#   'Humidity': 66,
#   'Cloudiness': 57,
#   'Wind Speed': 14.41,
#   'Country': 'CA'},
#  {'City': 'Shwebo',
#   'Lat': 22.5667,
#   'Lng': 95.7,
#   'Max Temp': 77.79,
#   'Current Description': 'overcast clouds',
#   'Humidity': 84,
#   'Cloudiness': 91,
#   'Wind Speed': 12.97,
#   'Country': 'MM'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 69.84,
#   'Current Description': 'overcast clouds',
#   'Humidity': 60,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'CA'},
#  {'City': 'Lagos',
#   'Lat': 6.5833,
#   'Lng': 3.75,
#   'Max Temp': 79.12,
#   'Current Description': 'scattered clouds',
#   'Humidity': 86,
#   'Cloudiness': 25,
#   'Wind Speed': 3.11,
#   'Country': 'NG'},
#  {'City': 'Choma',
#   'Lat': -16.8065,
#   'Lng': 26.9531,
#   'Max Temp': 52.54,
#   'Current Description': 'scattered clouds',
#   'Humidity': 53,
#   'Cloudiness': 27,
#   'Wind Speed': 2.08,
#   'Country': 'ZM'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 69.39,
#   'Current Description': 'light rain',
#   'Humidity': 78,
#   'Cloudiness': 46,
#   'Wind Speed': 10,
#   'Country': 'MU'},
#  {'City': 'Buraydah',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp': 91.85,
#   'Current Description': 'overcast clouds',
#   'Humidity': 15,
#   'Cloudiness': 99,
#   'Wind Speed': 7.14,
#   'Country': 'SA'},
#  {'City': 'Bara',
#   'Lat': 10.3744,
#   'Lng': 10.7288,
#   'Max Temp': 73.54,
#   'Current Description': 'light rain',
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 5.97,
#   'Country': 'NG'},
#  {'City': 'Hervey Bay',
#   'Lat': -25.2986,
#   'Lng': 152.8535,
#   'Max Temp': 57.31,
#   'Current Description': 'clear sky',
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 11.23,
#   'Country': 'AU'},
#  {'City': 'Mumford',
#   'Lat': 5.2618,
#   'Lng': -0.759,
#   'Max Temp': 75.96,
#   'Current Description': 'scattered clouds',
#   'Humidity': 86,
#   'Cloudiness': 30,
#   'Wind Speed': 8.68,
#   'Country': 'GH'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 77.11,
#   'Current Description': 'overcast clouds',
#   'Humidity': 89,
#   'Cloudiness': 96,
#   'Wind Speed': 6.73,
#   'Country': 'PH'},
#  {'City': 'Camacha',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 68.76,
#   'Current Description': 'few clouds',
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 17.27,
#   'Country': 'PT'},
#  {'City': 'Paamiut',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 45.84,
#   'Current Description': 'broken clouds',
#   'Humidity': 83,
#   'Cloudiness': 76,
#   'Wind Speed': 2.24,
#   'Country': 'GL'},
#  {'City': 'Marrakesh',
#   'Lat': 31.6315,
#   'Lng': -8.0083,
#   'Max Temp': 98.67,
#   'Current Description': 'broken clouds',
#   'Humidity': 19,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'MA'},
#  {'City': 'Kuloy',
#   'Lat': 61.0305,
#   'Lng': 42.4925,
#   'Max Temp': 57.63,
#   'Current Description': 'overcast clouds',
#   'Humidity': 98,
#   'Cloudiness': 99,
#   'Wind Speed': 4.61,
#   'Country': 'RU'},
#  {'City': 'Bure',
#   'Lat': 10.7,
#   'Lng': 37.0667,
#   'Max Temp': 58.12,
#   'Current Description': 'moderate rain',
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'ET'},
#  {'City': 'Jizan',
#   'Lat': 17.3333,
#   'Lng': 42.6667,
#   'Max Temp': 90.54,
#   'Current Description': 'broken clouds',
#   'Humidity': 54,
#   'Cloudiness': 64,
#   'Wind Speed': 3.6,
#   'Country': 'SA'},
#  {'City': 'Atikokan',
#   'Lat': 48.7555,
#   'Lng': -91.6216,
#   'Max Temp': 74.21,
#   'Current Description': 'clear sky',
#   'Humidity': 26,
#   'Cloudiness': 5,
#   'Wind Speed': 10.18,
#   'Country': 'CA'},
#  {'City': 'Maltahohe',
#   'Lat': -24.8333,
#   'Lng': 16.9833,
#   'Max Temp': 51.55,
#   'Current Description': 'clear sky',
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 12.59,
#   'Country': 'NA'},
#  {'City': 'Port Lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 56.52,
#   'Current Description': 'scattered clouds',
#   'Humidity': 58,
#   'Cloudiness': 34,
#   'Wind Speed': 19.08,
#   'Country': 'AU'},
#  {'City': 'Ponta Delgada',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 72.32,
#   'Current Description': 'broken clouds',
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'PT'},
#  {'City': 'Buzmeyin',
#   'Lat': 38.0507,
#   'Lng': 58.2056,
#   'Max Temp': 82.13,
#   'Current Description': 'broken clouds',
#   'Humidity': 51,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'TM'},
#  {'City': 'Mount Pleasant',
#   'Lat': 32.7941,
#   'Lng': -79.8626,
#   'Max Temp': 90.18,
#   'Current Description': 'clear sky',
#   'Humidity': 76,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 74.86,
#   'Current Description': 'few clouds',
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'US'},
#  {'City': 'Loudi',
#   'Lat': 27.7344,
#   'Lng': 111.9944,
#   'Max Temp': 75.97,
#   'Current Description': 'clear sky',
#   'Humidity': 89,
#   'Cloudiness': 3,
#   'Wind Speed': 0.83,
#   'Country': 'CN'},
#  {'City': 'Muzhi',
#   'Lat': 65.3667,
#   'Lng': 64.6667,
#   'Max Temp': 48.4,
#   'Current Description': 'overcast clouds',
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 9.75,
#   'Country': 'RU'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 44.44,
#   'Current Description': 'broken clouds',
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'SJ'},
#  {'City': 'Rincon',
#   'Lat': 32.296,
#   'Lng': -81.2354,
#   'Max Temp': 93.85,
#   'Current Description': 'scattered clouds',
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'US'},
#  {'City': 'Zonguldak',
#   'Lat': 41.25,
#   'Lng': 31.8333,
#   'Max Temp': 62.31,
#   'Current Description': 'clear sky',
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 4.38,
#   'Country': 'TR'},
#  {'City': 'Khairagarh',
#   'Lat': 26.95,
#   'Lng': 77.8167,
#   'Max Temp': 79.07,
#   'Current Description': 'overcast clouds',
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 6.62,
#   'Country': 'IN'},
#  {'City': 'Dickinson',
#   'Lat': 29.4608,
#   'Lng': -95.0513,
#   'Max Temp': 95.27,
#   'Current Description': 'scattered clouds',
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 3,
#   'Country': 'US'},
#  {'City': 'Kaeo',
#   'Lat': -35.1,
#   'Lng': 173.7833,
#   'Max Temp': 61.32,
#   'Current Description': 'broken clouds',
#   'Humidity': 89,
#   'Cloudiness': 61,
#   'Wind Speed': 11.23,
#   'Country': 'NZ'},
#  {'City': 'Chase',
#   'Lat': 50.8165,
#   'Lng': -119.6857,
#   'Max Temp': 92.37,
#   'Current Description': 'clear sky',
#   'Humidity': 18,
#   'Cloudiness': 4,
#   'Wind Speed': 1.95,
#   'Country': 'CA'},
#  {'City': 'Ambilobe',
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp': 64.53,
#   'Current Description': 'clear sky',
#   'Humidity': 91,
#   'Cloudiness': 3,
#   'Wind Speed': 3.65,
#   'Country': 'MG'},
#  {'City': 'Chakwal',
#   'Lat': 32.9334,
#   'Lng': 72.8585,
#   'Max Temp': 82.63,
#   'Current Description': 'broken clouds',
#   'Humidity': 74,
#   'Cloudiness': 76,
#   'Wind Speed': 4.63,
#   'Country': 'PK'},
#  {'City': 'Port Arthur',
#   'Lat': 38.8,
#   'Lng': 121.2667,
#   'Max Temp': 79.02,
#   'Current Description': 'light rain',
#   'Humidity': 90,
#   'Cloudiness': 38,
#   'Wind Speed': 18.14,
#   'Country': 'CN'},
#  {'City': 'Vila Do Maio',
#   'Lat': 15.1333,
#   'Lng': -23.2167,
#   'Max Temp': 77.79,
#   'Current Description': 'overcast clouds',
#   'Humidity': 76,
#   'Cloudiness': 99,
#   'Wind Speed': 7.23,
#   'Country': 'CV'},
#  {'City': 'Belen',
#   'Lat': 36.4891,
#   'Lng': 36.2233,
#   'Max Temp': 77.14,
#   'Current Description': 'clear sky',
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'TR'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 44.47,
#   'Current Description': 'overcast clouds',
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 13.22,
#   'Country': 'RU'},
#  {'City': 'Tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 74.64,
#   'Current Description': 'overcast clouds',
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 7.23,
#   'Country': 'IN'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 45.93,
#   'Current Description': 'overcast clouds',
#   'Humidity': 90,
#   'Cloudiness': 85,
#   'Wind Speed': 8.19,
#   'Country': 'CL'},
#  {'City': 'Bulolo',
#   'Lat': -7.2,
#   'Lng': 146.65,
#   'Max Temp': 72.73,
#   'Current Description': 'broken clouds',
#   'Humidity': 89,
#   'Cloudiness': 74,
#   'Wind Speed': 0.43,
#   'Country': 'PG'},
#  {'City': 'Lahaina',
#   'Lat': 20.8783,
#   'Lng': -156.6825,
#   'Max Temp': 86,
#   'Current Description': 'light intensity drizzle',
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Country': 'US'},
#  {'City': 'Gamboula',
#   'Lat': 4.1178,
#   'Lng': 15.1393,
#   'Max Temp': 68.07,
#   'Current Description': 'light rain',
#   'Humidity': 97,
#   'Cloudiness': 66,
#   'Wind Speed': 2.82,
#   'Country': 'CF'},
#  {'City': 'Acajutla',
#   'Lat': 13.5928,
#   'Lng': -89.8275,
#   'Max Temp': 98.94,
#   'Current Description': 'broken clouds',
#   'Humidity': 71,
#   'Cloudiness': 82,
#   'Wind Speed': 3.85,
#   'Country': 'SV'},
#  {'City': 'Darfo',
#   'Lat': 45.8779,
#   'Lng': 10.1812,
#   'Max Temp': 75.96,
#   'Current Description': 'clear sky',
#   'Humidity': 83,
#   'Cloudiness': 4,
#   'Wind Speed': 1.01,
#   'Country': 'IT'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 61.39,
#   'Current Description': 'broken clouds',
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 6.71,
#   'Country': 'RU'},
#  {'City': 'Champerico',
#   'Lat': 14.3,
#   'Lng': -91.9167,
#   'Max Temp': 84.34,
#   'Current Description': 'overcast clouds',
#   'Humidity': 68,
#   'Cloudiness': 89,
#   'Wind Speed': 3.58,
#   'Country': 'GT'},
#  {'City': 'Saint-Michel-Des-Saints',
#   'Lat': 46.6834,
#   'Lng': -73.9159,
#   'Max Temp': 57.94,
#   'Current Description': 'overcast clouds',
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 4.23,
#   'Country': 'CA'},
#  {'City': 'Porto Novo',
#   'Lat': 6.4965,
#   'Lng': 2.6036,
#   'Max Temp': 78.62,
#   'Current Description': 'overcast clouds',
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 6.08,
#   'Country': 'BJ'},
#  {'City': 'Tanggulangin',
#   'Lat': -7.4996,
#   'Lng': 112.6999,
#   'Max Temp': 75.16,
#   'Current Description': 'haze',
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'ID'},
#  {'City': 'Omsukchan',
#   'Lat': 62.5333,
#   'Lng': 155.8,
#   'Max Temp': 36.16,
#   'Current Description': 'light rain',
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 7.29,
#   'Country': 'RU'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 44.4,
#   'Current Description': 'overcast clouds',
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 5.7,
#   'Country': 'GL'},
#  {'City': 'Southbridge',
#   'Lat': 42.0751,
#   'Lng': -72.0334,
#   'Max Temp': 70.95,
#   'Current Description': 'light rain',
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'US'},
#  {'City': 'Orlik',
#   'Lat': 52.5178,
#   'Lng': 99.825,
#   'Max Temp': 49.42,
#   'Current Description': 'overcast clouds',
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 0.94,
#   'Country': 'RU'},
#  {'City': 'Tres Lagoas',
#   'Lat': -20.7511,
#   'Lng': -51.6783,
#   'Max Temp': 51.93,
#   'Current Description': 'clear sky',
#   'Humidity': 21,
#   'Cloudiness': 5,
#   'Wind Speed': 6.64,
#   'Country': 'BR'},
#  {'City': 'Tondano',
#   'Lat': 1.3038,
#   'Lng': 124.9112,
#   'Max Temp': 66.29,
#   'Current Description': 'scattered clouds',
#   'Humidity': 86,
#   'Cloudiness': 25,
#   'Wind Speed': 2.24,
#   'Country': 'ID'},
#  {'City': 'Anderson',
#   'Lat': 34.5334,
#   'Lng': -82.6499,
#   'Max Temp': 95.54,
#   'Current Description': 'clear sky',
#   'Humidity': 61,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US'},
#  {'City': 'Tuy Hoa',
#   'Lat': 13.0833,
#   'Lng': 109.3,
#   'Max Temp': 83.26,
#   'Current Description': 'scattered clouds',
#   'Humidity': 68,
#   'Cloudiness': 41,
#   'Wind Speed': 15.57,
#   'Country': 'VN'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 77.9,
#   'Current Description': 'thunderstorm with rain',
#   'Humidity': 92,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'MY'},
#  {'City': 'Bredy',
#   'Lat': 52.4153,
#   'Lng': 60.3411,
#   'Max Temp': 59.22,
#   'Current Description': 'broken clouds',
#   'Humidity': 51,
#   'Cloudiness': 73,
#   'Wind Speed': 9.17,
#   'Country': 'RU'},
#  {'City': 'Ketchikan',
#   'Lat': 55.3422,
#   'Lng': -131.6461,
#   'Max Temp': 68.47,
#   'Current Description': 'overcast clouds',
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US'},
#  {'City': 'Mapiripan',
#   'Lat': 2.8892,
#   'Lng': -72.1256,
#   'Max Temp': 81.77,
#   'Current Description': 'very heavy rain',
#   'Humidity': 79,
#   'Cloudiness': 38,
#   'Wind Speed': 1.48,
#   'Country': 'CO'},
#  {'City': 'Horasan',
#   'Lat': 40.0458,
#   'Lng': 42.1728,
#   'Max Temp': 57.79,
#   'Current Description': 'clear sky',
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 3.85,
#   'Country': 'TR'},
#  {'City': 'Hudson Bay',
#   'Lat': 52.85,
#   'Lng': -102.3842,
#   'Max Temp': 89.74,
#   'Current Description': 'overcast clouds',
#   'Humidity': 21,
#   'Cloudiness': 88,
#   'Wind Speed': 7.25,
#   'Country': 'CA'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 78.51,
#   'Current Description': 'light rain',
#   'Humidity': 75,
#   'Cloudiness': 77,
#   'Wind Speed': 12.59,
#   'Country': 'PF'},
#  {'City': 'Brae',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 55.31,
#   'Current Description': 'overcast clouds',
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 12.5,
#   'Country': 'GB'},
#  {'City': 'Liverpool',
#   'Lat': 53.4106,
#   'Lng': -2.9779,
#   'Max Temp': 59.18,
#   'Current Description': 'overcast clouds',
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 1.52,
#   'Country': 'GB'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 78.89,
#   'Current Description': 'light intensity drizzle',
#   'Humidity': 89,
# ...
#   'Cloudiness': 0,
#   'Wind Speed': 15.99,
#   'Country': 'PT'},
#  {'City': 'Podor',
#   'Lat': 16.6527,
#   'Lng': -14.9587,
#   'Max Temp': 87.75,
#   'Current Description': 'clear sky',
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'MR'},
#  {'City': 'Puerto Leguizamo',
#   'Lat': -0.1934,
#   'Lng': -74.7819,
#   'Max Temp': 73.53,
#   'Current Description': 'broken clouds',
#   'Humidity': 96,
#   'Cloudiness': 76,
#   'Wind Speed': 3.18,
#   'Country': 'CO'},
#  {'City': 'Belmonte',
#   'Lat': -15.8631,
#   'Lng': -38.8828,
#   'Max Temp': 73.9,
#   'Current Description': 'few clouds',
#   'Humidity': 89,
#   'Cloudiness': 12,
#   'Wind Speed': 9.35,
#   'Country': 'BR'},
#  {'City': 'Australind',
#   'Lat': -33.2667,
#   'Lng': 115.7167,
#   'Max Temp': 49.05,
#   'Current Description': 'light rain',
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 26.71,
#   'Country': 'AU'},
#  {'City': 'Cordoba',
#   'Lat': -31.4135,
#   'Lng': -64.1811,
#   'Max Temp': 55.76,
#   'Current Description': 'clear sky',
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Country': 'AR'},
#  {'City': 'Kirensk',
#   'Lat': 57.7853,
#   'Lng': 108.1119,
#   'Max Temp': 63.82,
#   'Current Description': 'clear sky',
#   'Humidity': 62,
#   'Cloudiness': 3,
#   'Wind Speed': 4.81,
#   'Country': 'RU'},
#  {'City': 'Dalaba',
#   'Lat': 10.7,
#   'Lng': -12.25,
#   'Max Temp': 61.48,
#   'Current Description': 'overcast clouds',
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.28,
#   'Country': 'GN'},
#  {'City': 'High Level',
#   'Lat': 58.5169,
#   'Lng': -117.136,
#   'Max Temp': 80.71,
#   'Current Description': 'scattered clouds',
#   'Humidity': 28,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'CA'},
#  {'City': 'Itubera',
#   'Lat': -13.7322,
#   'Lng': -39.1492,
#   'Max Temp': 71.01,
#   'Current Description': 'clear sky',
#   'Humidity': 96,
#   'Cloudiness': 4,
#   'Wind Speed': 2.21,
#   'Country': 'BR'},
#  {'City': 'Dubrovytsya',
#   'Lat': 51.5744,
#   'Lng': 26.565,
#   'Max Temp': 63.25,
#   'Current Description': 'clear sky',
#   'Humidity': 79,
#   'Cloudiness': 2,
#   'Wind Speed': 6.04,
#   'Country': 'UA'},
#  {'City': 'Kyabe',
#   'Lat': 9.4515,
#   'Lng': 18.9449,
#   'Max Temp': 71.92,
#   'Current Description': 'light rain',
#   'Humidity': 96,
#   'Cloudiness': 83,
#   'Wind Speed': 3.98,
#   'Country': 'TD'},
#  {'City': 'Asgabat',
#   'Lat': 37.95,
#   'Lng': 58.3833,
#   'Max Temp': 82.26,
#   'Current Description': 'broken clouds',
#   'Humidity': 51,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'TM'},
#  {'City': 'Saurimo',
#   'Lat': -9.6608,
#   'Lng': 20.3916,
#   'Max Temp': 59.95,
#   'Current Description': 'clear sky',
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 5.1,
#   'Country': 'AO'},
#  {'City': 'Aksu',
#   'Lat': 41.1231,
#   'Lng': 80.2644,
#   'Max Temp': 86.47,
#   'Current Description': 'overcast clouds',
#   'Humidity': 21,
#   'Cloudiness': 100,
#   'Wind Speed': 5.79,
#   'Country': 'CN'},
#  {'City': 'Rosetta',
#   'Lat': 31.4044,
#   'Lng': 30.4164,
#   'Max Temp': 78.62,
#   'Current Description': 'clear sky',
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 10.29,
#   'Country': 'EG'},
#  {'City': 'Lata',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 62.04,
#   'Current Description': 'clear sky',
#   'Humidity': 97,
#   'Cloudiness': 2,
#   'Wind Speed': 1.88,
#   'Country': 'PT'},
#  {'City': 'Mlonggo',
#   'Lat': -6.5333,
#   'Lng': 110.7,
#   'Max Temp': 76.89,
#   'Current Description': 'overcast clouds',
#   'Humidity': 79,
#   'Cloudiness': 93,
#   'Wind Speed': 5.68,
#   'Country': 'ID'},
#  {'City': 'Palmerston North',
#   'Lat': -40.35,
#   'Lng': 175.6167,
#   'Max Temp': 58.5,
#   'Current Description': 'broken clouds',
#   'Humidity': 82,
#   'Cloudiness': 60,
#   'Wind Speed': 1.72,
#   'Country': 'NZ'},
#  {'City': 'Banihal',
#   'Lat': 33.4167,
#   'Lng': 75.2,
#   'Max Temp': 67.48,
#   'Current Description': 'broken clouds',
#   'Humidity': 90,
#   'Cloudiness': 65,
#   'Wind Speed': 2.77,
#   'Country': 'IN'},
#  {'City': 'Celestun',
#   'Lat': 20.8667,
#   'Lng': -90.4,
#   'Max Temp': 82.65,
#   'Current Description': 'broken clouds',
#   'Humidity': 77,
#   'Cloudiness': 54,
#   'Wind Speed': 16.31,
#   'Country': 'MX'},
#  {'City': 'Abaetetuba',
#   'Lat': -1.7181,
#   'Lng': -48.8825,
#   'Max Temp': 80.64,
#   'Current Description': 'broken clouds',
#   'Humidity': 89,
#   'Cloudiness': 70,
#   'Wind Speed': 5.75,
#   'Country': 'BR'},
#  {'City': 'Andra',
#   'Lat': 62.5147,
#   'Lng': 65.8878,
#   'Max Temp': 40.19,
#   'Current Description': 'clear sky',
#   'Humidity': 97,
#   'Cloudiness': 8,
#   'Wind Speed': 4.09,
#   'Country': 'RU'},
#  {'City': 'Albury',
#   'Lat': -36.0833,
#   'Lng': 146.9167,
#   'Max Temp': 45.01,
#   'Current Description': 'overcast clouds',
#   'Humidity': 95,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'AU'},
#  {'City': 'Tsabong',
#   'Lat': -26.0217,
#   'Lng': 22.401,
#   'Max Temp': 52.47,
#   'Current Description': 'clear sky',
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 9.15,
#   'Country': 'BW'},
#  {'City': 'Sakakah',
#   'Lat': 29.9697,
#   'Lng': 40.2064,
#   'Max Temp': 90.97,
#   'Current Description': 'clear sky',
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 16.26,
#   'Country': 'SA'},
#  {'City': 'Pyu',
#   'Lat': 18.4833,
#   'Lng': 96.4333,
#   'Max Temp': 73.53,
#   'Current Description': 'broken clouds',
#   'Humidity': 98,
#   'Cloudiness': 67,
#   'Wind Speed': 4.09,
#   'Country': 'MM'},
#  {'City': 'Kofele',
#   'Lat': 7.0667,
#   'Lng': 38.7833,
#   'Max Temp': 49.82,
#   'Current Description': 'overcast clouds',
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 4.74,
#   'Country': 'ET'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 44.82,
#   'Current Description': 'light rain',
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 3.89,
#   'Country': 'NZ'},
#  {'City': 'La Roda',
#   'Lat': 39.2167,
#   'Lng': -2.15,
#   'Max Temp': 79.9,
#   'Current Description': 'clear sky',
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 10.4,
#   'Country': 'ES'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 55.62,
#   'Current Description': 'broken clouds',
#   'Humidity': 82,
#   'Cloudiness': 78,
#   'Wind Speed': 3.78,
#   'Country': 'GL'},
#  {'City': 'Severomuysk',
#   'Lat': 56.1481,
#   'Lng': 113.4267,
#   'Max Temp': 58.23,
#   'Current Description': 'clear sky',
#   'Humidity': 65,
#   'Cloudiness': 2,
#   'Wind Speed': 2.84,
#   'Country': 'RU'},
#  {'City': 'Matamoros',
#   'Lat': 25.5333,
#   'Lng': -103.25,
#   'Max Temp': 89.71,
#   'Current Description': 'broken clouds',
#   'Humidity': 29,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'MX'},
#  {'City': 'Porto Murtinho',
#   'Lat': -21.6989,
#   'Lng': -57.8825,
#   'Max Temp': 50.65,
#   'Current Description': 'broken clouds',
#   'Humidity': 25,
#   'Cloudiness': 51,
#   'Wind Speed': 5.26,
#   'Country': 'BR'},
#  {'City': 'Benghazi',
#   'Lat': 32.1167,
#   'Lng': 20.0667,
#   'Max Temp': 81.7,
#   'Current Description': 'clear sky',
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 15.46,
#   'Country': 'LY'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 78.91,
#   'Current Description': 'broken clouds',
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'VU'},
#  {'City': 'Kizukuri',
#   'Lat': 40.8061,
#   'Lng': 140.3861,
#   'Max Temp': 75.94,
#   'Current Description': 'few clouds',
#   'Humidity': 79,
#   'Cloudiness': 13,
#   'Wind Speed': 3.62,
#   'Country': 'JP'},
#  {'City': 'Sideropolis',
#   'Lat': -28.5978,
#   'Lng': -49.4244,
#   'Max Temp': 41.76,
#   'Current Description': 'clear sky',
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 3.31,
#   'Country': 'BR'},
#  {'City': 'Kirakira',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 84.09,
#   'Current Description': 'clear sky',
#   'Humidity': 70,
#   'Cloudiness': 6,
#   'Wind Speed': 6.78,
#   'Country': 'SB'},
#  {'City': 'Sioux Lookout',
#   'Lat': 50.1001,
#   'Lng': -91.917,
#   'Max Temp': 70.18,
#   'Current Description': 'smoke',
#   'Humidity': 34,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'CA'},
#  {'City': 'Sistranda',
#   'Lat': 63.7256,
#   'Lng': 8.834,
#   'Max Temp': 57.16,
#   'Current Description': 'broken clouds',
#   'Humidity': 86,
#   'Cloudiness': 55,
#   'Wind Speed': 15.17,
#   'Country': 'NO'},
#  {'City': 'Kampene',
#   'Lat': -3.6,
#   'Lng': 26.6667,
#   'Max Temp': 71.98,
#   'Current Description': 'broken clouds',
#   'Humidity': 62,
#   'Cloudiness': 64,
#   'Wind Speed': 0.83,
#   'Country': 'CD'},
#  {'City': 'Chaiya',
#   'Lat': 9.3862,
#   'Lng': 99.1986,
#   'Max Temp': 79.14,
#   'Current Description': 'overcast clouds',
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 8.57,
#   'Country': 'TH'},
#  {'City': 'Borogontsy',
#   'Lat': 62.6683,
#   'Lng': 131.1683,
#   'Max Temp': 61.75,
#   'Current Description': 'clear sky',
#   'Humidity': 51,
#   'Cloudiness': 4,
#   'Wind Speed': 5.59,
#   'Country': 'RU'},
#  {'City': 'Novodugino',
#   'Lat': 55.6305,
#   'Lng': 34.2842,
#   'Max Temp': 63.05,
#   'Current Description': 'overcast clouds',
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.5,
#   'Country': 'RU'},
#  {'City': 'Tiarei',
#   'Lat': -17.5333,
#   'Lng': -149.3333,
#   'Max Temp': 82.42,
#   'Current Description': 'light rain',
#   'Humidity': 77,
#   'Cloudiness': 64,
#   'Wind Speed': 0.34,
#   'Country': 'PF'},
#  {'City': 'Gap',
#   'Lat': 44.6667,
#   'Lng': 6,
#   'Max Temp': 56.84,
#   'Current Description': 'broken clouds',
#   'Humidity': 65,
#   'Cloudiness': 77,
#   'Wind Speed': 1.79,
#   'Country': 'FR'},
#  {'City': 'Aasiaat',
#   'Lat': 68.7098,
#   'Lng': -52.8699,
#   'Max Temp': 40.55,
#   'Current Description': 'overcast clouds',
#   'Humidity': 90,
#   'Cloudiness': 87,
#   'Wind Speed': 7.58,
#   'Country': 'GL'},
#  {'City': 'Yamada',
#   'Lat': 39.4667,
#   'Lng': 141.95,
#   'Max Temp': 77.81,
#   'Current Description': 'light rain',
#   'Humidity': 81,
#   'Cloudiness': 33,
#   'Wind Speed': 7.94,
#   'Country': 'JP'},
#  {'City': 'Qasigiannguit',
#   'Lat': 68.8193,
#   'Lng': -51.1922,
#   'Max Temp': 52.05,
#   'Current Description': 'broken clouds',
#   'Humidity': 79,
#   'Cloudiness': 82,
#   'Wind Speed': 2.82,
#   'Country': 'GL'},
#  {'City': 'Manavgat',
#   'Lat': 36.7867,
#   'Lng': 31.4431,
#   'Max Temp': 90.01,
#   'Current Description': 'clear sky',
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 9.35,
#   'Country': 'TR'},
#  {'City': 'Salinopolis',
#   'Lat': -0.6136,
#   'Lng': -47.3561,
#   'Max Temp': 78.26,
#   'Current Description': 'clear sky',
#   'Humidity': 86,
#   'Cloudiness': 10,
#   'Wind Speed': 9.62,
#   'Country': 'BR'},
#  {'City': 'Hope',
#   'Lat': 33.6671,
#   'Lng': -93.5916,
#   'Max Temp': 98.65,
#   'Current Description': 'scattered clouds',
#   'Humidity': 33,
#   'Cloudiness': 35,
#   'Wind Speed': 3.11,
#   'Country': 'US'},
#  {'City': 'Inongo',
#   'Lat': -1.95,
#   'Lng': 18.2667,
#   'Max Temp': 72.36,
#   'Current Description': 'scattered clouds',
#   'Humidity': 39,
#   'Cloudiness': 40,
#   'Wind Speed': 3.91,
#   'Country': 'CD'},
#  {'City': 'Kot Diji',
#   'Lat': 27.3427,
#   'Lng': 68.7083,
#   'Max Temp': 88.54,
#   'Current Description': 'broken clouds',
#   'Humidity': 60,
#   'Cloudiness': 84,
#   'Wind Speed': 15.68,
#   'Country': 'PK'},
#  {'City': 'Nowy Targ',
#   'Lat': 49.4778,
#   'Lng': 20.0323,
#   'Max Temp': 63.34,
#   'Current Description': 'clear sky',
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 3.06,
#   'Country': 'PL'},
#  {'City': 'Lakatoro',
#   'Lat': -16.0999,
#   'Lng': 167.4164,
#   'Max Temp': 81,
#   'Current Description': 'scattered clouds',
#   'Humidity': 72,
#   'Cloudiness': 37,
#   'Wind Speed': 0.72,
#   'Country': 'VU'},
#  {'City': 'Ancona',
#   'Lat': 43.55,
#   'Lng': 13.1667,
#   'Max Temp': 77.49,
#   'Current Description': 'clear sky',
#   'Humidity': 56,
#   'Cloudiness': 4,
#   'Wind Speed': 3.44,
#   'Country': 'IT'},
#  {'City': 'Hamada',
#   'Lat': 34.8833,
#   'Lng': 132.0833,
#   'Max Temp': 80.01,
#   'Current Description': 'scattered clouds',
#   'Humidity': 64,
#   'Cloudiness': 31,
#   'Wind Speed': 3.74,
#   'Country': 'JP'},
#  {'City': 'Asfi',
#   'Lat': 32.2994,
#   'Lng': -9.2372,
#   'Max Temp': 70.77,
#   'Current Description': 'scattered clouds',
#   'Humidity': 82,
#   'Cloudiness': 42,
#   'Wind Speed': 16.11,
#   'Country': 'MA'},
#  {'City': 'Parainen',
#   'Lat': 60.3067,
#   'Lng': 22.301,
#   'Max Temp': 65.14,
#   'Current Description': 'clear sky',
#   'Humidity': 69,
#   'Cloudiness': 5,
#   'Wind Speed': 18.52,
#   'Country': 'FI'},
#  {'City': 'Donji Milanovac',
#   'Lat': 44.4627,
#   'Lng': 22.1523,
#   'Max Temp': 72.45,
#   'Current Description': 'clear sky',
#   'Humidity': 62,
#   'Cloudiness': 3,
#   'Wind Speed': 3.78,
#   'Country': 'RS'},
#  {'City': 'Loganville',
#   'Lat': 33.839,
#   'Lng': -83.9007,
#   'Max Temp': 95.07,
#   'Current Description': 'clear sky',
#   'Humidity': 58,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US'},
#  {'City': 'Bismarck',
#   'Lat': 46.8083,
#   'Lng': -100.7837,
#   'Max Temp': 78.64,
#   'Current Description': 'broken clouds',
#   'Humidity': 45,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'US'},
#  {'City': 'Kabare',
#   'Lat': -2.4683,
#   'Lng': 28.8242,
#   'Max Temp': 60.6,
#   'Current Description': 'scattered clouds',
#   'Humidity': 72,
#   'Cloudiness': 32,
#   'Wind Speed': 0.6,
#   'Country': 'CD'},
#  {'City': 'Antofagasta',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 64.22,
#   'Current Description': 'few clouds',
#   'Humidity': 67,
#   'Cloudiness': 13,
#   'Wind Speed': 6.76,
#   'Country': 'CL'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 69.98,
#   'Current Description': 'few clouds',
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'CA'},
#  {'City': 'Sudak',
#   'Lat': 44.85,
#   'Lng': 34.9667,
#   'Max Temp': 76.46,
#   'Current Description': 'clear sky',
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'UA'},
#  {'City': 'South Lake Tahoe',
#   'Lat': 38.9332,
#   'Lng': -119.9844,
#   'Max Temp': 87.78,
#   'Current Description': 'overcast clouds',
#   'Humidity': 45,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'US'},
#  {'City': 'La Aldea',
#   'Lat': 20.9,
#   'Lng': -101.4833,
#   'Max Temp': 82.63,
#   'Current Description': 'broken clouds',
#   'Humidity': 44,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'MX'},
#  {'City': 'Kamaishi',
#   'Lat': 39.2667,
#   'Lng': 141.8833,
#   'Max Temp': 76.91,
#   'Current Description': 'broken clouds',
#   'Humidity': 86,
#   'Cloudiness': 52,
#   'Wind Speed': 7.36,
#   'Country': 'JP'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 76.89,
#   'Current Description': 'scattered clouds',
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'NU'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 77.9,
#   'Current Description': 'overcast clouds',
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 13.91,
#   'Country': 'BR'},
#  {'City': 'Nesna',
#   'Lat': 66.1967,
#   'Lng': 13.0213,
#   'Max Temp': 54.18,
#   'Current Description': 'clear sky',
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 7.34,
#   'Country': 'NO'},
#  {'City': 'Shingu',
#   'Lat': 33.7333,
#   'Lng': 135.9833,
#   'Max Temp': 79.92,
#   'Current Description': 'clear sky',
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 1.48,
#   'Country': 'JP'},
#  {'City': 'Nargana',
#   'Lat': 9.4428,
#   'Lng': -78.5906,
#   'Max Temp': 81.7,
#   'Current Description': 'overcast clouds',
#   'Humidity': 80,
#   'Cloudiness': 96,
#   'Wind Speed': 6.82,
#   'Country': 'PA'},
#  {'City': 'Necochea',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp': 48.04,
#   'Current Description': 'clear sky',
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 7.31,
#   'Country': 'AR'},
#  {'City': 'Hirara',
#   'Lat': 24.8,
#   'Lng': 125.2833,
#   'Max Temp': 82.67,
#   'Current Description': 'few clouds',
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'JP'},
#  {'City': 'Padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 69.85,
#   'Current Description': 'overcast clouds',
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 3.62,
#   'Country': 'ID'},
#  {'City': 'Wau',
#   'Lat': 7.7029,
#   'Lng': 27.9953,
#   'Max Temp': 71.11,
#   'Current Description': 'overcast clouds',
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 3.91,
#   'Country': 'SS'},
#  {'City': 'Changji',
#   'Lat': 44.0167,
#   'Lng': 87.3167,
#   'Max Temp': 77.79,
#   'Current Description': 'clear sky',
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Country': 'CN'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                    City      Lat       Lng  Max Temp Current Description  \
# 0    Comodoro Rivadavia -45.8667  -67.5000     64.26           clear sky
# 1            Chokurdakh  70.6333  147.9167     43.20     overcast clouds
# 2         Mar Del Plata -38.0023  -57.5575     54.09           clear sky
# 3       Arraial Do Cabo -22.9661  -42.0278     69.76       broken clouds
# 4             Busselton -33.6500  115.3333     49.08     overcast clouds
# ..                  ...      ...       ...       ...                 ...
# 671            Necochea -38.5473  -58.7368     48.04           clear sky
# 672              Hirara  24.8000  125.2833     82.67          few clouds
# 673              Padang  -0.9492  100.3543     69.85     overcast clouds
# 674                 Wau   7.7029   27.9953     71.11     overcast clouds
# 675             Changji  44.0167   87.3167     77.79           clear sky
#
#      Humidity  Cloudiness  Wind Speed Country
# 0          20           0       10.36      AR
# 1          56          94        6.67      RU
# 2          71           0        4.61      AR
# 3          49          75       14.97      BR
# 4          72         100       27.18      AU
# ..        ...         ...         ...     ...
# 671        62           0        7.31      AR
# 672        94          20        4.61      JP
# 673        79         100        3.62      ID
# 674        95         100        3.91      SS
# 675        38           0        6.71      CN
#
# [676 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
